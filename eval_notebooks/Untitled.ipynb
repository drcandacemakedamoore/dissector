# %%
import numpy as np
import SimpleITK as sitk

# %%
example_image = sitk.ReadImage('myosegmenTUM/HV001_3/ImageData/HV001_3_FAT/HV001_3_FAT_stack1.nii')

# %%
array =sitk.GetArrayFromImage(example_image)

# %%
array.shape
# Out:
# (65, 672, 672)
