# %% [markdown]
# # Compare muscle map - whole body model - to ground truth (extended metrics)

# %% [markdown]
# Note: this notebook was developed with assistance from Generative AI. The end cross schecks the results against a hand-coded earlier version

# %%
# libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import SimpleITK as sitk
from dissector.evaluation import binary_cross_entropy, boundary_iou_3d

# %%
# !pwd
# above should be about ~something~/~someProjects~/dissector/eval_notebooks/myosegmenTUM
# Out:
# /c/Projects/dissector/eval_notebooks/myosegmenTUM

# %%
# dilation distance used for boundary_iou_3d
BOUNDARY_DISTANCE = 1

# %% [markdown]
# ## Right gracilis

# %%
results_r_gracilis = []
for file in os.listdir(os.path.join("..", "MuscleMap_segs")):
    print(file)
    if file[0] == 'H':
        gt_name = file[:7] + "/SegmentationMasks/combined_gt_stack" + file[-13] + ".mha"
    else:
        gt_name = file[:6] + "/SegmentationMasks/combined_gt_stack" + file[-13] + ".mha"
    print(gt_name)

    segment_image = sitk.ReadImage(os.path.join("..", "MuscleMap_segs", file))
    gt_image = sitk.ReadImage(gt_name)
    segment_image.CopyInformation(gt_image)

    gt = sitk.Cast(gt_image == 5, sitk.sitkUInt8)
    pred = sitk.Cast(segment_image == 7152, sitk.sitkUInt8)

    gt_arr = sitk.GetArrayFromImage(gt).astype(float)
    pred_arr = sitk.GetArrayFromImage(pred).astype(float)

    dice_filter = sitk.LabelOverlapMeasuresImageFilter()
    dice_filter.Execute(gt, pred)
    right_grac_dice_lower = dice_filter.GetDiceCoefficient()
    right_JaccardCoeffi = dice_filter.GetJaccardCoefficient()
    right_VolumeSimilar = dice_filter.GetVolumeSimilarity()
    right_FalseNegative = dice_filter.GetFalseNegativeError()
    right_FalsePositive = dice_filter.GetFalsePositiveError()

    hd_filter = sitk.HausdorffDistanceImageFilter()
    hd_filter.Execute(gt, pred)
    right_grac_hd_lower = hd_filter.GetHausdorffDistance()

    bce = binary_cross_entropy(gt_arr, pred_arr)
    biou = boundary_iou_3d(BOUNDARY_DISTANCE, gt_arr, pred_arr)

    results_r_gracilis.append({
        "image": gt_name,
        "pred_label": file,
        "R_gracilis_lower_dice:": right_grac_dice_lower,
        "R_gracilis_lower_Hausdorff:": right_grac_hd_lower,
        "R_gracilis_jaccard": right_JaccardCoeffi,
        "R_gracilis_volume_similarity": right_VolumeSimilar,
        "R_gracilis_falseNegative": right_FalseNegative,
        "R_gracilis_falsePostivie": right_FalsePositive,
        "R_gracilis_binary_cross_entropy": bce,
        "R_gracilis_boundary_iou_3d": biou,
    })

df_r_gracilis = pd.DataFrame(results_r_gracilis)
df_r_gracilis.to_csv('../MuscleMap_results_WB/df_r_gracilis_NEW.csv')
df_r_gracilis
# Out:
# HV001_1_FATFRACTION_stack1_dseg.nii.gz
# HV001_1/SegmentationMasks/combined_gt_stack1.mha
# HV001_1_FATFRACTION_stack2_dseg.nii.gz
# HV001_1/SegmentationMasks/combined_gt_stack2.mha
# HV001_2_FATFRACTION_stack1_dseg.nii.gz
# HV001_2/SegmentationMasks/combined_gt_stack1.mha
# HV001_2_FATFRACTION_stack2_dseg.nii.gz
# HV001_2/SegmentationMasks/combined_gt_stack2.mha
# HV001_3_FATFRACTION_stack1_dseg.nii.gz
# HV001_3/SegmentationMasks/combined_gt_stack1.mha
# HV001_3_FATFRACTION_stack2_dseg.nii.gz
# HV001_3/SegmentationMasks/combined_gt_stack2.mha
# HV002_1_FATFRACTION_stack1_dseg.nii.gz
# HV002_1/SegmentationMasks/combined_gt_stack1.mha
# HV002_1_FATFRACTION_stack2_dseg.nii.gz
# HV002_1/SegmentationMasks/combined_gt_stack2.mha
# HV002_2_FATFRACTION_stack1_dseg.nii.gz
# HV002_2/SegmentationMasks/combined_gt_stack1.mha
# HV002_2_FATFRACTION_stack2_dseg.nii.gz
# HV002_2/SegmentationMasks/combined_gt_stack2.mha
# HV002_3_FATFRACTION_stack1_dseg.nii.gz
# HV002_3/SegmentationMasks/combined_gt_stack1.mha
# HV002_3_FATFRACTION_stack2_dseg.nii.gz
# HV002_3/SegmentationMasks/combined_gt_stack2.mha
# HV003_1_FATFRACTION_stack1_dseg.nii.gz
# HV003_1/SegmentationMasks/combined_gt_stack1.mha
# HV003_1_FATFRACTION_stack2_dseg.nii.gz
# HV003_1/SegmentationMasks/combined_gt_stack2.mha
# HV003_2_FATFRACTION_stack1_dseg.nii.gz
# HV003_2/SegmentationMasks/combined_gt_stack1.mha
# HV003_2_FATFRACTION_stack2_dseg.nii.gz
# HV003_2/SegmentationMasks/combined_gt_stack2.mha
# HV003_3_FATFRACTION_stack1_dseg.nii.gz
# HV003_3/SegmentationMasks/combined_gt_stack1.mha
# HV003_3_FATFRACTION_stack2_dseg.nii.gz
# HV003_3/SegmentationMasks/combined_gt_stack2.mha
# HV004_1_FATFRACTION_stack1_dseg.nii.gz
# HV004_1/SegmentationMasks/combined_gt_stack1.mha
# HV004_1_FATFRACTION_stack2_dseg.nii.gz
# HV004_1/SegmentationMasks/combined_gt_stack2.mha
# HV005_1_FATFRACTION_stack1_dseg.nii.gz
# HV005_1/SegmentationMasks/combined_gt_stack1.mha
# HV005_1_FATFRACTION_stack2_dseg.nii.gz
# HV005_1/SegmentationMasks/combined_gt_stack2.mha
# HV006_1_FATFRACTION_stack1_dseg.nii.gz
# HV006_1/SegmentationMasks/combined_gt_stack1.mha
# HV006_1_FATFRACTION_stack2_dseg.nii.gz
# HV006_1/SegmentationMasks/combined_gt_stack2.mha
# HV007_1_FATFRACTION_stack1_dseg.nii.gz
# HV007_1/SegmentationMasks/combined_gt_stack1.mha
# HV007_1_FATFRACTION_stack2_dseg.nii.gz
# HV007_1/SegmentationMasks/combined_gt_stack2.mha
# HV008_1_FATFRACTION_stack1_dseg.nii.gz
# HV008_1/SegmentationMasks/combined_gt_stack1.mha
# HV008_1_FATFRACTION_stack2_dseg.nii.gz
# HV008_1/SegmentationMasks/combined_gt_stack2.mha
# HV009_1_FATFRACTION_stack1_dseg.nii.gz
# HV009_1/SegmentationMasks/combined_gt_stack1.mha
# HV009_1_FATFRACTION_stack2_dseg.nii.gz
# HV009_1/SegmentationMasks/combined_gt_stack2.mha
# HV010_1_FATFRACTION_stack1_dseg.nii.gz
# HV010_1/SegmentationMasks/combined_gt_stack1.mha
# HV010_1_FATFRACTION_stack2_dseg.nii.gz
# HV010_1/SegmentationMasks/combined_gt_stack2.mha
# HV011_1_FATFRACTION_stack1_dseg.nii.gz
# HV011_1/SegmentationMasks/combined_gt_stack1.mha
# HV011_1_FATFRACTION_stack2_dseg.nii.gz
# HV011_1/SegmentationMasks/combined_gt_stack2.mha
# HV012_1_FATFRACTION_stack1_dseg.nii.gz
# HV012_1/SegmentationMasks/combined_gt_stack1.mha
# HV012_1_FATFRACTION_stack2_dseg.nii.gz
# HV012_1/SegmentationMasks/combined_gt_stack2.mha
# HV013_1_FATFRACTION_stack1_dseg.nii.gz
# HV013_1/SegmentationMasks/combined_gt_stack1.mha
# HV013_1_FATFRACTION_stack2_dseg.nii.gz
# HV013_1/SegmentationMasks/combined_gt_stack2.mha
# HV014_1_FATFRACTION_stack1_dseg.nii.gz
# HV014_1/SegmentationMasks/combined_gt_stack1.mha
# HV014_1_FATFRACTION_stack2_dseg.nii.gz
# HV014_1/SegmentationMasks/combined_gt_stack2.mha
# HV015_1_FATFRACTION_stack1_dseg.nii.gz
# HV015_1/SegmentationMasks/combined_gt_stack1.mha
# HV015_1_FATFRACTION_stack2_dseg.nii.gz
# HV015_1/SegmentationMasks/combined_gt_stack2.mha
# P001_1_FATFRACTION_stack1_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack1.mha
# P001_1_FATFRACTION_stack2_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack2.mha
# P001_1_FATFRACTION_stack3_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack3.mha
# P002_1_FATFRACTION_stack1_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack1.mha
# P002_1_FATFRACTION_stack2_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack2.mha
# P002_1_FATFRACTION_stack3_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack3.mha
# P003_1_FATFRACTION_stack1_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack1.mha
# P003_1_FATFRACTION_stack2_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack2.mha
# P003_1_FATFRACTION_stack3_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack3.mha
# P004_1_FATFRACTION_stack1_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack1.mha
# P004_1_FATFRACTION_stack2_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack2.mha
# P004_1_FATFRACTION_stack3_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack3.mha
#                                                image  \
# 0   HV001_1/SegmentationMasks/combined_gt_stack1.mha
# 1   HV001_1/SegmentationMasks/combined_gt_stack2.mha
# 2   HV001_2/SegmentationMasks/combined_gt_stack1.mha
# 3   HV001_2/SegmentationMasks/combined_gt_stack2.mha
# 4   HV001_3/SegmentationMasks/combined_gt_stack1.mha
# 5   HV001_3/SegmentationMasks/combined_gt_stack2.mha
# 6   HV002_1/SegmentationMasks/combined_gt_stack1.mha
# 7   HV002_1/SegmentationMasks/combined_gt_stack2.mha
# 8   HV002_2/SegmentationMasks/combined_gt_stack1.mha
# 9   HV002_2/SegmentationMasks/combined_gt_stack2.mha
# 10  HV002_3/SegmentationMasks/combined_gt_stack1.mha
# 11  HV002_3/SegmentationMasks/combined_gt_stack2.mha
# 12  HV003_1/SegmentationMasks/combined_gt_stack1.mha
# 13  HV003_1/SegmentationMasks/combined_gt_stack2.mha
# 14  HV003_2/SegmentationMasks/combined_gt_stack1.mha
# 15  HV003_2/SegmentationMasks/combined_gt_stack2.mha
# 16  HV003_3/SegmentationMasks/combined_gt_stack1.mha
# 17  HV003_3/SegmentationMasks/combined_gt_stack2.mha
# 18  HV004_1/SegmentationMasks/combined_gt_stack1.mha
# 19  HV004_1/SegmentationMasks/combined_gt_stack2.mha
# 20  HV005_1/SegmentationMasks/combined_gt_stack1.mha
# 21  HV005_1/SegmentationMasks/combined_gt_stack2.mha
# 22  HV006_1/SegmentationMasks/combined_gt_stack1.mha
# 23  HV006_1/SegmentationMasks/combined_gt_stack2.mha
# 24  HV007_1/SegmentationMasks/combined_gt_stack1.mha
# 25  HV007_1/SegmentationMasks/combined_gt_stack2.mha
# 26  HV008_1/SegmentationMasks/combined_gt_stack1.mha
# 27  HV008_1/SegmentationMasks/combined_gt_stack2.mha
# 28  HV009_1/SegmentationMasks/combined_gt_stack1.mha
# 29  HV009_1/SegmentationMasks/combined_gt_stack2.mha
# 30  HV010_1/SegmentationMasks/combined_gt_stack1.mha
# 31  HV010_1/SegmentationMasks/combined_gt_stack2.mha
# 32  HV011_1/SegmentationMasks/combined_gt_stack1.mha
# 33  HV011_1/SegmentationMasks/combined_gt_stack2.mha
# 34  HV012_1/SegmentationMasks/combined_gt_stack1.mha
# 35  HV012_1/SegmentationMasks/combined_gt_stack2.mha
# 36  HV013_1/SegmentationMasks/combined_gt_stack1.mha
# 37  HV013_1/SegmentationMasks/combined_gt_stack2.mha
# 38  HV014_1/SegmentationMasks/combined_gt_stack1.mha
# 39  HV014_1/SegmentationMasks/combined_gt_stack2.mha
# 40  HV015_1/SegmentationMasks/combined_gt_stack1.mha
# 41  HV015_1/SegmentationMasks/combined_gt_stack2.mha
# 42   P001_1/SegmentationMasks/combined_gt_stack1.mha
# 43   P001_1/SegmentationMasks/combined_gt_stack2.mha
# 44   P001_1/SegmentationMasks/combined_gt_stack3.mha
# 45   P002_1/SegmentationMasks/combined_gt_stack1.mha
# 46   P002_1/SegmentationMasks/combined_gt_stack2.mha
# 47   P002_1/SegmentationMasks/combined_gt_stack3.mha
# 48   P003_1/SegmentationMasks/combined_gt_stack1.mha
# 49   P003_1/SegmentationMasks/combined_gt_stack2.mha
# 50   P003_1/SegmentationMasks/combined_gt_stack3.mha
# 51   P004_1/SegmentationMasks/combined_gt_stack1.mha
# 52   P004_1/SegmentationMasks/combined_gt_stack2.mha
# 53   P004_1/SegmentationMasks/combined_gt_stack3.mha
#
#                                 pred_label  R_gracilis_lower_dice:  \
# 0   HV001_1_FATFRACTION_stack1_dseg.nii.gz                0.864141
# 1   HV001_1_FATFRACTION_stack2_dseg.nii.gz                0.880848
# 2   HV001_2_FATFRACTION_stack1_dseg.nii.gz                0.844484
# 3   HV001_2_FATFRACTION_stack2_dseg.nii.gz                0.867442
# 4   HV001_3_FATFRACTION_stack1_dseg.nii.gz                0.864027
# 5   HV001_3_FATFRACTION_stack2_dseg.nii.gz                0.889236
# 6   HV002_1_FATFRACTION_stack1_dseg.nii.gz                0.836608
# 7   HV002_1_FATFRACTION_stack2_dseg.nii.gz                0.873970
# 8   HV002_2_FATFRACTION_stack1_dseg.nii.gz                0.855348
# 9   HV002_2_FATFRACTION_stack2_dseg.nii.gz                0.868235
# 10  HV002_3_FATFRACTION_stack1_dseg.nii.gz                0.840097
# 11  HV002_3_FATFRACTION_stack2_dseg.nii.gz                0.874371
# 12  HV003_1_FATFRACTION_stack1_dseg.nii.gz                0.853742
# 13  HV003_1_FATFRACTION_stack2_dseg.nii.gz                0.887382
# 14  HV003_2_FATFRACTION_stack1_dseg.nii.gz                0.866999
# 15  HV003_2_FATFRACTION_stack2_dseg.nii.gz                0.897668
# 16  HV003_3_FATFRACTION_stack1_dseg.nii.gz                0.853384
# 17  HV003_3_FATFRACTION_stack2_dseg.nii.gz                0.884630
# 18  HV004_1_FATFRACTION_stack1_dseg.nii.gz                0.873810
# 19  HV004_1_FATFRACTION_stack2_dseg.nii.gz                0.893368
# 20  HV005_1_FATFRACTION_stack1_dseg.nii.gz                0.854804
# 21  HV005_1_FATFRACTION_stack2_dseg.nii.gz                0.867030
# 22  HV006_1_FATFRACTION_stack1_dseg.nii.gz                0.875903
# 23  HV006_1_FATFRACTION_stack2_dseg.nii.gz                0.890950
# 24  HV007_1_FATFRACTION_stack1_dseg.nii.gz                0.882372
# 25  HV007_1_FATFRACTION_stack2_dseg.nii.gz                0.861855
# 26  HV008_1_FATFRACTION_stack1_dseg.nii.gz                0.888543
# 27  HV008_1_FATFRACTION_stack2_dseg.nii.gz                0.884022
# 28  HV009_1_FATFRACTION_stack1_dseg.nii.gz                0.823265
# 29  HV009_1_FATFRACTION_stack2_dseg.nii.gz                0.863967
# 30  HV010_1_FATFRACTION_stack1_dseg.nii.gz                0.870252
# 31  HV010_1_FATFRACTION_stack2_dseg.nii.gz                0.853489
# 32  HV011_1_FATFRACTION_stack1_dseg.nii.gz                0.860814
# 33  HV011_1_FATFRACTION_stack2_dseg.nii.gz                0.838202
# 34  HV012_1_FATFRACTION_stack1_dseg.nii.gz                0.524480
# 35  HV012_1_FATFRACTION_stack2_dseg.nii.gz                0.564573
# 36  HV013_1_FATFRACTION_stack1_dseg.nii.gz                0.752900
# 37  HV013_1_FATFRACTION_stack2_dseg.nii.gz                0.813065
# 38  HV014_1_FATFRACTION_stack1_dseg.nii.gz                0.587609
# 39  HV014_1_FATFRACTION_stack2_dseg.nii.gz                0.550059
# 40  HV015_1_FATFRACTION_stack1_dseg.nii.gz                0.667257
# 41  HV015_1_FATFRACTION_stack2_dseg.nii.gz                0.711508
# 42   P001_1_FATFRACTION_stack1_dseg.nii.gz                0.814462
# 43   P001_1_FATFRACTION_stack2_dseg.nii.gz                0.874351
# 44   P001_1_FATFRACTION_stack3_dseg.nii.gz                0.615238
# 45   P002_1_FATFRACTION_stack1_dseg.nii.gz                0.730533
# 46   P002_1_FATFRACTION_stack2_dseg.nii.gz                0.876268
# 47   P002_1_FATFRACTION_stack3_dseg.nii.gz                0.787232
# 48   P003_1_FATFRACTION_stack1_dseg.nii.gz                0.648627
# 49   P003_1_FATFRACTION_stack2_dseg.nii.gz                0.764458
# 50   P003_1_FATFRACTION_stack3_dseg.nii.gz                0.731580
# 51   P004_1_FATFRACTION_stack1_dseg.nii.gz                0.834543
# 52   P004_1_FATFRACTION_stack2_dseg.nii.gz                0.823305
# 53   P004_1_FATFRACTION_stack3_dseg.nii.gz                0.114050
#
#     R_gracilis_lower_Hausdorff:  R_gracilis_jaccard  \
# 0                     11.045361            0.760782
# 1                     16.000000            0.787067
# 2                     14.866069            0.730828
# 3                     20.000000            0.765913
# 4                      9.055385            0.760606
# 5                     16.031220            0.800562
# 6                     20.248457            0.719111
# 7                     24.000000            0.776152
# 8                     18.681542            0.747257
# 9                     24.041631            0.767151
# 10                    17.549929            0.724282
# 11                    24.103942            0.776784
# 12                    22.360680            0.744807
# 13                    24.083189            0.797562
# 14                    12.165525            0.765224
# 15                    20.099751            0.814335
# 16                    10.049876            0.744264
# 17                    28.017851            0.793127
# 18                    10.677078            0.775900
# 19                    20.099751            0.807286
# 20                     7.071068            0.746426
# 21                    40.311289            0.765272
# 22                     9.219544            0.779206
# 23                    12.369317            0.803346
# 24                    10.816654            0.789504
# 25                    24.413111            0.757245
# 26                     5.830952            0.799440
# 27                    20.248457            0.792149
# 28                    29.966648            0.699618
# 29                     7.810250            0.760512
# 30                    12.041595            0.770306
# 31                    28.017851            0.744423
# 32                    12.041595            0.755640
# 33                    24.020824            0.721470
# 34                    16.763055            0.355454
# 35                    12.083046            0.393314
# 36                    16.763055            0.603721
# 37                    12.000000            0.685012
# 38                    20.493902            0.416039
# 39                    32.526912            0.379367
# 40                    12.649111            0.500664
# 41                    12.000000            0.552202
# 42                    13.152946            0.686998
# 43                     4.582576            0.776752
# 44                     5.385165            0.444291
# 45                     4.000000            0.575465
# 46                     5.000000            0.779784
# 47                     4.242641            0.649120
# 48                     9.165151            0.479977
# 49                     5.099020            0.618723
# 50                     8.602325            0.576765
# 51                     6.164414            0.716065
# 52                     4.582576            0.699676
# 53                     9.219544            0.060473
#
#     R_gracilis_volume_similarity  R_gracilis_falseNegative  \
# 0                      -0.070575                  0.165313
# 1                      -0.020081                  0.127908
# 2                      -0.096734                  0.194477
# 3                      -0.084335                  0.167656
# 4                      -0.052282                  0.157984
# 5                       0.048875                  0.088489
# 6                       0.068192                  0.133861
# 7                      -0.039984                  0.143160
# 8                       0.044249                  0.125299
# 9                       0.115447                  0.078578
# 10                     -0.100430                  0.200071
# 11                      0.057247                  0.099864
# 12                      0.128707                  0.087538
# 13                      0.123799                  0.054065
# 14                      0.141577                  0.066952
# 15                      0.129938                  0.039960
# 16                      0.173300                  0.065655
# 17                      0.144913                  0.046266
# 18                      0.074721                  0.092277
# 19                      0.023139                  0.096175
# 20                     -0.005071                  0.147358
# 21                     -0.028241                  0.145042
# 22                      0.005789                  0.121554
# 23                      0.007649                  0.105629
# 24                     -0.013416                  0.123508
# 25                      0.032525                  0.123897
# 26                      0.045309                  0.090861
# 27                      0.025421                  0.104597
# 28                     -0.026302                  0.187421
# 29                     -0.011369                  0.140917
# 30                      0.008880                  0.125867
# 31                     -0.021150                  0.155442
# 32                      0.030472                  0.125867
# 33                     -0.009888                  0.165921
# 34                     -0.771114                  0.621466
# 35                     -0.848620                  0.603616
# 36                     -0.422165                  0.378324
# 37                     -0.274272                  0.284989
# 38                     -0.807580                  0.581412
# 39                     -0.721256                  0.595731
# 40                     -0.610607                  0.488811
# 41                     -0.411262                  0.409846
# 42                     -0.265674                  0.281042
# 43                     -0.096615                  0.165940
# 44                     -0.736813                  0.550398
# 45                     -0.528551                  0.422172
# 46                     -0.223858                  0.211939
# 47                     -0.414401                  0.347886
# 48                     -0.689569                  0.517672
# 49                     -0.461268                  0.378810
# 50                     -0.533123                  0.422388
# 51                     -0.226875                  0.250481
# 52                     -0.313207                  0.288170
# 53                     -1.771901                  0.939527
#
#     R_gracilis_falsePostivie  R_gracilis_binary_cross_entropy  \
# 0                   0.000057                         0.002467
# 1                   0.000086                         0.003031
# 2                   0.000062                         0.002903
# 3                   0.000068                         0.003219
# 4                   0.000067                         0.002665
# 5                   0.000106                         0.002806
# 6                   0.000171                         0.004558
# 7                   0.000077                         0.002951
# 8                   0.000139                         0.003870
# 9                   0.000160                         0.003588
# 10                  0.000090                         0.004230
# 11                  0.000120                         0.003158
# 12                  0.000176                         0.003940
# 13                  0.000153                         0.003178
# 14                  0.000180                         0.003790
# 15                  0.000148                         0.002911
# 16                  0.000201                         0.004076
# 17                  0.000171                         0.003384
# 18                  0.000075                         0.001857
# 19                  0.000049                         0.001414
# 20                  0.000092                         0.003019
# 21                  0.000073                         0.002643
# 22                  0.000083                         0.002613
# 23                  0.000107                         0.003337
# 24                  0.000100                         0.003418
# 25                  0.000132                         0.003802
# 26                  0.000106                         0.002831
# 27                  0.000072                         0.002085
# 28                  0.000092                         0.003195
# 29                  0.000073                         0.002441
# 30                  0.000042                         0.001300
# 31                  0.000074                         0.002564
# 32                  0.000049                         0.001410
# 33                  0.000086                         0.002847
# 34                  0.000015                         0.002485
# 35                  0.000006                         0.007515
# 36                  0.000021                         0.004564
# 37                  0.000052                         0.006315
# 38                  0.000006                         0.009047
# 39                  0.000053                         0.008523
# 40                  0.000018                         0.007213
# 41                  0.000097                         0.010912
# 42                  0.000105                         0.011906
# 43                  0.000158                         0.008231
# 44                  0.000008                         0.005786
# 45                  0.000003                         0.004681
# 46                  0.000027                         0.009024
# 47                  0.000004                         0.004700
# 48                  0.000005                         0.009182
# 49                  0.000007                         0.010426
# 50                  0.000001                         0.005921
# 51                  0.000071                         0.007288
# 52                  0.000024                         0.006850
# 53                  0.000000                         0.002197
#
#     R_gracilis_boundary_iou_3d
# 0                     0.610530
# 1                     0.702395
# 2                     0.579530
# 3                     0.670560
# 4                     0.607997
# 5                     0.697885
# 6                     0.554251
# 7                     0.663251
# 8                     0.590948
# 9                     0.644771
# 10                    0.562151
# 11                    0.653324
# 12                    0.577152
# 13                    0.652359
# 14                    0.585233
# 15                    0.672448
# 16                    0.551854
# 17                    0.645430
# 18                    0.689001
# 19                    0.751729
# 20                    0.612646
# 21                    0.655873
# 22                    0.609433
# 23                    0.688694
# 24                    0.601662
# 25                    0.595748
# 26                    0.655567
# 27                    0.701664
# 28                    0.554164
# 29                    0.690417
# 30                    0.675052
# 31                    0.680043
# 32                    0.655738
# 33                    0.653571
# 34                    0.379803
# 35                    0.392953
# 36                    0.480538
# 37                    0.622778
# 38                    0.340064
# 39                    0.439161
# 40                    0.399174
# 41                    0.481052
# 42                    0.565184
# 43                    0.647146
# 44                    0.359751
# 45                    0.457902
# 46                    0.576979
# 47                    0.476830
# 48                    0.394268
# 49                    0.470527
# 50                    0.455968
# 51                    0.589266
# 52                    0.523652
# 53                    0.130358

# %% [markdown]
# ## Left gracilis

# %%
results_l_gracilis = []
for file in os.listdir(os.path.join("..", "MuscleMap_segs")):
    print(file)
    if file[0] == 'H':
        gt_name = file[:7] + "/SegmentationMasks/combined_gt_stack" + file[-13] + ".mha"
    else:
        gt_name = file[:6] + "/SegmentationMasks/combined_gt_stack" + file[-13] + ".mha"
    print(gt_name)

    segment_image = sitk.ReadImage(os.path.join("..", "MuscleMap_segs", file))
    gt_image = sitk.ReadImage(gt_name)
    segment_image.CopyInformation(gt_image)

    gt = sitk.Cast(gt_image == 1, sitk.sitkUInt8)
    pred = sitk.Cast(segment_image == 7151, sitk.sitkUInt8)

    gt_arr = sitk.GetArrayFromImage(gt).astype(float)
    pred_arr = sitk.GetArrayFromImage(pred).astype(float)

    dice_filter = sitk.LabelOverlapMeasuresImageFilter()
    dice_filter.Execute(gt, pred)
    left_grac_dice_lower = dice_filter.GetDiceCoefficient()
    left_JaccardCoeffi = dice_filter.GetJaccardCoefficient()
    left_VolumeSimilar = dice_filter.GetVolumeSimilarity()
    left_FalseNegative = dice_filter.GetFalseNegativeError()
    left_FalsePositive = dice_filter.GetFalsePositiveError()

    hd_filter = sitk.HausdorffDistanceImageFilter()
    hd_filter.Execute(gt, pred)
    left_grac_hd_lower = hd_filter.GetHausdorffDistance()

    bce = binary_cross_entropy(gt_arr, pred_arr)
    biou = boundary_iou_3d(BOUNDARY_DISTANCE, gt_arr, pred_arr)

    results_l_gracilis.append({
        "image": gt_name,
        "pred_label": file,
        "L_gracilis_lower_dice:": left_grac_dice_lower,
        "L_gracilis_lower_Hausdorff:": left_grac_hd_lower,
        "L_gracilis_jaccard": left_JaccardCoeffi,
        "L_gracilis_volume_similarity": left_VolumeSimilar,
        "L_gracilis_falseNegative": left_FalseNegative,
        "L_gracilis_falsePostivie": left_FalsePositive,
        "L_gracilis_binary_cross_entropy": bce,
        "L_gracilis_boundary_iou_3d": biou,
    })

df_l_gracilis = pd.DataFrame(results_l_gracilis)
df_l_gracilis.to_csv('../MuscleMap_results_WB/df_l_gracilis_NEW.csv')
df_l_gracilis
# Out:
# HV001_1_FATFRACTION_stack1_dseg.nii.gz
# HV001_1/SegmentationMasks/combined_gt_stack1.mha
# HV001_1_FATFRACTION_stack2_dseg.nii.gz
# HV001_1/SegmentationMasks/combined_gt_stack2.mha
# HV001_2_FATFRACTION_stack1_dseg.nii.gz
# HV001_2/SegmentationMasks/combined_gt_stack1.mha
# HV001_2_FATFRACTION_stack2_dseg.nii.gz
# HV001_2/SegmentationMasks/combined_gt_stack2.mha
# HV001_3_FATFRACTION_stack1_dseg.nii.gz
# HV001_3/SegmentationMasks/combined_gt_stack1.mha
# HV001_3_FATFRACTION_stack2_dseg.nii.gz
# HV001_3/SegmentationMasks/combined_gt_stack2.mha
# HV002_1_FATFRACTION_stack1_dseg.nii.gz
# HV002_1/SegmentationMasks/combined_gt_stack1.mha
# HV002_1_FATFRACTION_stack2_dseg.nii.gz
# HV002_1/SegmentationMasks/combined_gt_stack2.mha
# HV002_2_FATFRACTION_stack1_dseg.nii.gz
# HV002_2/SegmentationMasks/combined_gt_stack1.mha
# HV002_2_FATFRACTION_stack2_dseg.nii.gz
# HV002_2/SegmentationMasks/combined_gt_stack2.mha
# HV002_3_FATFRACTION_stack1_dseg.nii.gz
# HV002_3/SegmentationMasks/combined_gt_stack1.mha
# HV002_3_FATFRACTION_stack2_dseg.nii.gz
# HV002_3/SegmentationMasks/combined_gt_stack2.mha
# HV003_1_FATFRACTION_stack1_dseg.nii.gz
# HV003_1/SegmentationMasks/combined_gt_stack1.mha
# HV003_1_FATFRACTION_stack2_dseg.nii.gz
# HV003_1/SegmentationMasks/combined_gt_stack2.mha
# HV003_2_FATFRACTION_stack1_dseg.nii.gz
# HV003_2/SegmentationMasks/combined_gt_stack1.mha
# HV003_2_FATFRACTION_stack2_dseg.nii.gz
# HV003_2/SegmentationMasks/combined_gt_stack2.mha
# HV003_3_FATFRACTION_stack1_dseg.nii.gz
# HV003_3/SegmentationMasks/combined_gt_stack1.mha
# HV003_3_FATFRACTION_stack2_dseg.nii.gz
# HV003_3/SegmentationMasks/combined_gt_stack2.mha
# HV004_1_FATFRACTION_stack1_dseg.nii.gz
# HV004_1/SegmentationMasks/combined_gt_stack1.mha
# HV004_1_FATFRACTION_stack2_dseg.nii.gz
# HV004_1/SegmentationMasks/combined_gt_stack2.mha
# HV005_1_FATFRACTION_stack1_dseg.nii.gz
# HV005_1/SegmentationMasks/combined_gt_stack1.mha
# HV005_1_FATFRACTION_stack2_dseg.nii.gz
# HV005_1/SegmentationMasks/combined_gt_stack2.mha
# HV006_1_FATFRACTION_stack1_dseg.nii.gz
# HV006_1/SegmentationMasks/combined_gt_stack1.mha
# HV006_1_FATFRACTION_stack2_dseg.nii.gz
# HV006_1/SegmentationMasks/combined_gt_stack2.mha
# HV007_1_FATFRACTION_stack1_dseg.nii.gz
# HV007_1/SegmentationMasks/combined_gt_stack1.mha
# HV007_1_FATFRACTION_stack2_dseg.nii.gz
# HV007_1/SegmentationMasks/combined_gt_stack2.mha
# HV008_1_FATFRACTION_stack1_dseg.nii.gz
# HV008_1/SegmentationMasks/combined_gt_stack1.mha
# HV008_1_FATFRACTION_stack2_dseg.nii.gz
# HV008_1/SegmentationMasks/combined_gt_stack2.mha
# HV009_1_FATFRACTION_stack1_dseg.nii.gz
# HV009_1/SegmentationMasks/combined_gt_stack1.mha
# HV009_1_FATFRACTION_stack2_dseg.nii.gz
# HV009_1/SegmentationMasks/combined_gt_stack2.mha
# HV010_1_FATFRACTION_stack1_dseg.nii.gz
# HV010_1/SegmentationMasks/combined_gt_stack1.mha
# HV010_1_FATFRACTION_stack2_dseg.nii.gz
# HV010_1/SegmentationMasks/combined_gt_stack2.mha
# HV011_1_FATFRACTION_stack1_dseg.nii.gz
# HV011_1/SegmentationMasks/combined_gt_stack1.mha
# HV011_1_FATFRACTION_stack2_dseg.nii.gz
# HV011_1/SegmentationMasks/combined_gt_stack2.mha
# HV012_1_FATFRACTION_stack1_dseg.nii.gz
# HV012_1/SegmentationMasks/combined_gt_stack1.mha
# HV012_1_FATFRACTION_stack2_dseg.nii.gz
# HV012_1/SegmentationMasks/combined_gt_stack2.mha
# HV013_1_FATFRACTION_stack1_dseg.nii.gz
# HV013_1/SegmentationMasks/combined_gt_stack1.mha
# HV013_1_FATFRACTION_stack2_dseg.nii.gz
# HV013_1/SegmentationMasks/combined_gt_stack2.mha
# HV014_1_FATFRACTION_stack1_dseg.nii.gz
# HV014_1/SegmentationMasks/combined_gt_stack1.mha
# HV014_1_FATFRACTION_stack2_dseg.nii.gz
# HV014_1/SegmentationMasks/combined_gt_stack2.mha
# HV015_1_FATFRACTION_stack1_dseg.nii.gz
# HV015_1/SegmentationMasks/combined_gt_stack1.mha
# HV015_1_FATFRACTION_stack2_dseg.nii.gz
# HV015_1/SegmentationMasks/combined_gt_stack2.mha
# P001_1_FATFRACTION_stack1_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack1.mha
# P001_1_FATFRACTION_stack2_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack2.mha
# P001_1_FATFRACTION_stack3_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack3.mha
# P002_1_FATFRACTION_stack1_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack1.mha
# P002_1_FATFRACTION_stack2_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack2.mha
# P002_1_FATFRACTION_stack3_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack3.mha
# P003_1_FATFRACTION_stack1_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack1.mha
# P003_1_FATFRACTION_stack2_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack2.mha
# P003_1_FATFRACTION_stack3_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack3.mha
# P004_1_FATFRACTION_stack1_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack1.mha
# P004_1_FATFRACTION_stack2_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack2.mha
# P004_1_FATFRACTION_stack3_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack3.mha
#                                                image  \
# 0   HV001_1/SegmentationMasks/combined_gt_stack1.mha
# 1   HV001_1/SegmentationMasks/combined_gt_stack2.mha
# 2   HV001_2/SegmentationMasks/combined_gt_stack1.mha
# 3   HV001_2/SegmentationMasks/combined_gt_stack2.mha
# 4   HV001_3/SegmentationMasks/combined_gt_stack1.mha
# 5   HV001_3/SegmentationMasks/combined_gt_stack2.mha
# 6   HV002_1/SegmentationMasks/combined_gt_stack1.mha
# 7   HV002_1/SegmentationMasks/combined_gt_stack2.mha
# 8   HV002_2/SegmentationMasks/combined_gt_stack1.mha
# 9   HV002_2/SegmentationMasks/combined_gt_stack2.mha
# 10  HV002_3/SegmentationMasks/combined_gt_stack1.mha
# 11  HV002_3/SegmentationMasks/combined_gt_stack2.mha
# 12  HV003_1/SegmentationMasks/combined_gt_stack1.mha
# 13  HV003_1/SegmentationMasks/combined_gt_stack2.mha
# 14  HV003_2/SegmentationMasks/combined_gt_stack1.mha
# 15  HV003_2/SegmentationMasks/combined_gt_stack2.mha
# 16  HV003_3/SegmentationMasks/combined_gt_stack1.mha
# 17  HV003_3/SegmentationMasks/combined_gt_stack2.mha
# 18  HV004_1/SegmentationMasks/combined_gt_stack1.mha
# 19  HV004_1/SegmentationMasks/combined_gt_stack2.mha
# 20  HV005_1/SegmentationMasks/combined_gt_stack1.mha
# 21  HV005_1/SegmentationMasks/combined_gt_stack2.mha
# 22  HV006_1/SegmentationMasks/combined_gt_stack1.mha
# 23  HV006_1/SegmentationMasks/combined_gt_stack2.mha
# 24  HV007_1/SegmentationMasks/combined_gt_stack1.mha
# 25  HV007_1/SegmentationMasks/combined_gt_stack2.mha
# 26  HV008_1/SegmentationMasks/combined_gt_stack1.mha
# 27  HV008_1/SegmentationMasks/combined_gt_stack2.mha
# 28  HV009_1/SegmentationMasks/combined_gt_stack1.mha
# 29  HV009_1/SegmentationMasks/combined_gt_stack2.mha
# 30  HV010_1/SegmentationMasks/combined_gt_stack1.mha
# 31  HV010_1/SegmentationMasks/combined_gt_stack2.mha
# 32  HV011_1/SegmentationMasks/combined_gt_stack1.mha
# 33  HV011_1/SegmentationMasks/combined_gt_stack2.mha
# 34  HV012_1/SegmentationMasks/combined_gt_stack1.mha
# 35  HV012_1/SegmentationMasks/combined_gt_stack2.mha
# 36  HV013_1/SegmentationMasks/combined_gt_stack1.mha
# 37  HV013_1/SegmentationMasks/combined_gt_stack2.mha
# 38  HV014_1/SegmentationMasks/combined_gt_stack1.mha
# 39  HV014_1/SegmentationMasks/combined_gt_stack2.mha
# 40  HV015_1/SegmentationMasks/combined_gt_stack1.mha
# 41  HV015_1/SegmentationMasks/combined_gt_stack2.mha
# 42   P001_1/SegmentationMasks/combined_gt_stack1.mha
# 43   P001_1/SegmentationMasks/combined_gt_stack2.mha
# 44   P001_1/SegmentationMasks/combined_gt_stack3.mha
# 45   P002_1/SegmentationMasks/combined_gt_stack1.mha
# 46   P002_1/SegmentationMasks/combined_gt_stack2.mha
# 47   P002_1/SegmentationMasks/combined_gt_stack3.mha
# 48   P003_1/SegmentationMasks/combined_gt_stack1.mha
# 49   P003_1/SegmentationMasks/combined_gt_stack2.mha
# 50   P003_1/SegmentationMasks/combined_gt_stack3.mha
# 51   P004_1/SegmentationMasks/combined_gt_stack1.mha
# 52   P004_1/SegmentationMasks/combined_gt_stack2.mha
# 53   P004_1/SegmentationMasks/combined_gt_stack3.mha
#
#                                 pred_label  L_gracilis_lower_dice:  \
# 0   HV001_1_FATFRACTION_stack1_dseg.nii.gz                0.847848
# 1   HV001_1_FATFRACTION_stack2_dseg.nii.gz                0.840353
# 2   HV001_2_FATFRACTION_stack1_dseg.nii.gz                0.858697
# 3   HV001_2_FATFRACTION_stack2_dseg.nii.gz                0.828016
# 4   HV001_3_FATFRACTION_stack1_dseg.nii.gz                0.835699
# 5   HV001_3_FATFRACTION_stack2_dseg.nii.gz                0.827036
# 6   HV002_1_FATFRACTION_stack1_dseg.nii.gz                0.828220
# 7   HV002_1_FATFRACTION_stack2_dseg.nii.gz                0.810118
# 8   HV002_2_FATFRACTION_stack1_dseg.nii.gz                0.843304
# 9   HV002_2_FATFRACTION_stack2_dseg.nii.gz                0.825252
# 10  HV002_3_FATFRACTION_stack1_dseg.nii.gz                0.822905
# 11  HV002_3_FATFRACTION_stack2_dseg.nii.gz                0.799270
# 12  HV003_1_FATFRACTION_stack1_dseg.nii.gz                0.860442
# 13  HV003_1_FATFRACTION_stack2_dseg.nii.gz                0.861113
# 14  HV003_2_FATFRACTION_stack1_dseg.nii.gz                0.871045
# 15  HV003_2_FATFRACTION_stack2_dseg.nii.gz                0.868981
# 16  HV003_3_FATFRACTION_stack1_dseg.nii.gz                0.873149
# 17  HV003_3_FATFRACTION_stack2_dseg.nii.gz                0.872159
# 18  HV004_1_FATFRACTION_stack1_dseg.nii.gz                0.842237
# 19  HV004_1_FATFRACTION_stack2_dseg.nii.gz                0.864217
# 20  HV005_1_FATFRACTION_stack1_dseg.nii.gz                0.876601
# 21  HV005_1_FATFRACTION_stack2_dseg.nii.gz                0.847379
# 22  HV006_1_FATFRACTION_stack1_dseg.nii.gz                0.866490
# 23  HV006_1_FATFRACTION_stack2_dseg.nii.gz                0.891334
# 24  HV007_1_FATFRACTION_stack1_dseg.nii.gz                0.838013
# 25  HV007_1_FATFRACTION_stack2_dseg.nii.gz                0.879244
# 26  HV008_1_FATFRACTION_stack1_dseg.nii.gz                0.819093
# 27  HV008_1_FATFRACTION_stack2_dseg.nii.gz                0.846113
# 28  HV009_1_FATFRACTION_stack1_dseg.nii.gz                0.826998
# 29  HV009_1_FATFRACTION_stack2_dseg.nii.gz                0.851636
# 30  HV010_1_FATFRACTION_stack1_dseg.nii.gz                0.828219
# 31  HV010_1_FATFRACTION_stack2_dseg.nii.gz                0.824043
# 32  HV011_1_FATFRACTION_stack1_dseg.nii.gz                0.804588
# 33  HV011_1_FATFRACTION_stack2_dseg.nii.gz                0.817722
# 34  HV012_1_FATFRACTION_stack1_dseg.nii.gz                0.657738
# 35  HV012_1_FATFRACTION_stack2_dseg.nii.gz                0.710018
# 36  HV013_1_FATFRACTION_stack1_dseg.nii.gz                0.821020
# 37  HV013_1_FATFRACTION_stack2_dseg.nii.gz                0.779724
# 38  HV014_1_FATFRACTION_stack1_dseg.nii.gz                0.591572
# 39  HV014_1_FATFRACTION_stack2_dseg.nii.gz                0.659606
# 40  HV015_1_FATFRACTION_stack1_dseg.nii.gz                0.600518
# 41  HV015_1_FATFRACTION_stack2_dseg.nii.gz                0.607965
# 42   P001_1_FATFRACTION_stack1_dseg.nii.gz                0.806296
# 43   P001_1_FATFRACTION_stack2_dseg.nii.gz                0.871031
# 44   P001_1_FATFRACTION_stack3_dseg.nii.gz                0.692271
# 45   P002_1_FATFRACTION_stack1_dseg.nii.gz                0.762408
# 46   P002_1_FATFRACTION_stack2_dseg.nii.gz                0.812115
# 47   P002_1_FATFRACTION_stack3_dseg.nii.gz                0.852108
# 48   P003_1_FATFRACTION_stack1_dseg.nii.gz                0.742486
# 49   P003_1_FATFRACTION_stack2_dseg.nii.gz                0.773347
# 50   P003_1_FATFRACTION_stack3_dseg.nii.gz                0.647169
# 51   P004_1_FATFRACTION_stack1_dseg.nii.gz                0.812812
# 52   P004_1_FATFRACTION_stack2_dseg.nii.gz                0.828410
# 53   P004_1_FATFRACTION_stack3_dseg.nii.gz                0.073363
#
#     L_gracilis_lower_Hausdorff:  L_gracilis_jaccard  \
# 0                      8.306624            0.735882
# 1                     12.206556            0.724663
# 2                      6.403124            0.752383
# 3                     20.199010            0.706508
# 4                      8.124038            0.717769
# 5                     16.248077            0.705083
# 6                     26.832816            0.706805
# 7                     24.020824            0.680839
# 8                     20.639767            0.729062
# 9                     24.000000            0.702493
# 10                    22.203603            0.699098
# 11                    18.138357            0.665653
# 12                    21.954498            0.755066
# 13                    20.049938            0.756101
# 14                    19.646883            0.771550
# 15                    20.322401            0.768317
# 16                    14.456832            0.774858
# 17                    20.420578            0.773300
# 18                     9.000000            0.727470
# 19                    24.103942            0.760899
# 20                    12.041595            0.780312
# 21                    32.140317            0.735175
# 22                     8.000000            0.764431
# 23                    16.031220            0.803969
# 24                     8.246211            0.721190
# 25                    16.492423            0.784510
# 26                    10.246951            0.693613
# 27                    20.024984            0.733272
# 28                    13.038405            0.705027
# 29                     9.000000            0.741608
# 30                    12.041595            0.706803
# 31                    16.309506            0.700743
# 32                    12.083046            0.673064
# 33                    20.223748            0.691650
# 34                    16.031220            0.490022
# 35                     5.656854            0.550409
# 36                     4.242641            0.696382
# 37                    12.083046            0.638974
# 38                    24.207437            0.420023
# 39                    14.594520            0.492099
# 40                    12.409674            0.429100
# 41                    20.322401            0.436746
# 42                    11.575837            0.675457
# 43                     6.082763            0.771527
# 44                     6.324555            0.529368
# 45                     4.242641            0.616042
# 46                     5.830952            0.683664
# 47                     3.741657            0.742324
# 48                     6.082763            0.590440
# 49                     5.000000            0.630453
# 50                    11.401754            0.478381
# 51                     5.000000            0.684654
# 52                     5.385165            0.707082
# 53                     9.055385            0.038079
#
#     L_gracilis_volume_similarity  L_gracilis_falseNegative  \
# 0                      -0.021016                  0.160969
# 1                       0.014421                  0.153543
# 2                      -0.063328                  0.167658
# 3                       0.066260                  0.143612
# 4                      -0.042314                  0.181616
# 5                      -0.030429                  0.185358
# 6                       0.053324                  0.149093
# 7                       0.177269                  0.111094
# 8                       0.085814                  0.118891
# 9                       0.149547                  0.108054
# 10                      0.132036                  0.118928
# 11                      0.187482                  0.118056
# 12                      0.152408                  0.068580
# 13                      0.146962                  0.070593
# 14                      0.107010                  0.079715
# 15                      0.153343                  0.058860
# 16                      0.126383                  0.067953
# 17                      0.160932                  0.051521
# 18                     -0.065849                  0.184609
# 19                      0.001670                  0.135061
# 20                      0.084096                  0.084921
# 21                      0.183199                  0.067175
# 22                      0.028041                  0.121189
# 23                      0.066120                  0.078191
# 24                     -0.134985                  0.214970
# 25                     -0.003507                  0.122295
# 26                      0.186447                  0.096699
# 27                      0.051592                  0.131483
# 28                      0.042911                  0.154870
# 29                      0.007958                  0.144962
# 30                     -0.131129                  0.222742
# 31                      0.095633                  0.134575
# 32                      0.064091                  0.168775
# 33                      0.107317                  0.135912
# 34                     -0.627330                  0.499311
# 35                     -0.548942                  0.442892
# 36                     -0.262465                  0.274225
# 37                     -0.163369                  0.279158
# 38                     -0.788815                  0.575754
# 39                     -0.473477                  0.466657
# 40                     -0.728152                  0.559762
# 41                     -0.629934                  0.537657
# 42                     -0.302198                  0.299542
# 43                      0.011590                  0.123892
# 44                     -0.547826                  0.456579
# 45                     -0.465291                  0.381486
# 46                     -0.375393                  0.316227
# 47                     -0.290318                  0.255905
# 48                     -0.501762                  0.406430
# 49                     -0.228861                  0.306061
# 50                     -0.701255                  0.520839
# 51                     -0.357585                  0.310471
# 52                     -0.327520                  0.288161
# 53                     -1.853273                  0.961921
#
#     L_gracilis_falsePostivie  L_gracilis_binary_cross_entropy  \
# 0               6.707813e-05                         0.002322
# 1               1.215557e-04                         0.003747
# 2               5.358208e-05                         0.002225
# 3               1.478659e-04                         0.003994
# 4               7.287550e-05                         0.002695
# 5               1.063817e-04                         0.003758
# 6               1.498394e-04                         0.004178
# 7               1.978321e-04                         0.004345
# 8               1.476535e-04                         0.003734
# 9               1.920028e-04                         0.004332
# 10              1.874414e-04                         0.004398
# 11              2.018522e-04                         0.004433
# 12              1.889241e-04                         0.003936
# 13              1.826906e-04                         0.003849
# 14              1.604580e-04                         0.003653
# 15              1.776815e-04                         0.003611
# 16              1.663205e-04                         0.003576
# 17              1.865251e-04                         0.003687
# 18              5.085101e-05                         0.002071
# 19              5.619459e-05                         0.001800
# 20              1.232782e-04                         0.002962
# 21              1.799673e-04                         0.003623
# 22              9.200638e-05                         0.002683
# 23              1.239764e-04                         0.003062
# 24              5.982995e-05                         0.003304
# 25              7.328891e-05                         0.002396
# 26              1.982360e-04                         0.004215
# 27              9.915060e-05                         0.002736
# 28              1.048829e-04                         0.003006
# 29              8.457382e-05                         0.002654
# 30              3.196614e-05                         0.001666
# 31              1.219726e-04                         0.003090
# 32              7.534875e-05                         0.002086
# 33              1.293842e-04                         0.003221
# 34              7.840124e-06                         0.003024
# 35              2.017227e-05                         0.012137
# 36              3.256479e-05                         0.003932
# 37              1.516674e-04                         0.007762
# 38              8.737745e-06                         0.008198
# 39              5.489704e-05                         0.005808
# 40              2.035325e-05                         0.007397
# 41              6.515171e-05                         0.010672
# 42              9.177976e-05                         0.013418
# 43              2.904107e-04                         0.008940
# 44              1.781387e-05                         0.005222
# 45              3.690933e-06                         0.005710
# 46              6.383404e-07                         0.020432
# 47              2.418423e-06                         0.004214
# 48              6.110549e-06                         0.007639
# 49              1.650651e-04                         0.010729
# 50              1.654712e-06                         0.008530
# 51              1.069720e-05                         0.007678
# 52              9.805326e-06                         0.006917
# 53              0.000000e+00                         0.003365
#
#     L_gracilis_boundary_iou_3d
# 0                     0.594375
# 1                     0.646513
# 2                     0.630302
# 3                     0.630639
# 4                     0.576947
# 5                     0.622553
# 6                     0.569621
# 7                     0.562935
# 8                     0.575537
# 9                     0.585631
# 10                    0.559196
# 11                    0.533181
# 12                    0.595213
# 13                    0.635344
# 14                    0.616544
# 15                    0.640821
# 16                    0.611941
# 17                    0.644087
# 18                    0.655386
# 19                    0.701044
# 20                    0.644347
# 21                    0.609782
# 22                    0.596328
# 23                    0.691280
# 24                    0.542921
# 25                    0.692467
# 26                    0.547713
# 27                    0.625537
# 28                    0.573025
# 29                    0.659284
# 30                    0.611310
# 31                    0.608135
# 32                    0.556698
# 33                    0.595435
# 34                    0.416845
# 35                    0.375113
# 36                    0.575561
# 37                    0.556591
# 38                    0.372098
# 39                    0.571277
# 40                    0.374910
# 41                    0.442580
# 42                    0.540420
# 43                    0.696819
# 44                    0.454442
# 45                    0.479252
# 46                    0.341410
# 47                    0.572947
# 48                    0.483482
# 49                    0.489382
# 50                    0.355171
# 51                    0.544450
# 52                    0.534358
# 53                    0.093541

# %% [markdown]
# ## Right sartorius

# %%
results_r_sart = []
for file in os.listdir(os.path.join("..", "MuscleMap_segs")):
    print(file)
    if file[0] == 'H':
        gt_name = file[:7] + "/SegmentationMasks/combined_gt_stack" + file[-13] + ".mha"
    else:
        gt_name = file[:6] + "/SegmentationMasks/combined_gt_stack" + file[-13] + ".mha"
    print(gt_name)

    segment_image = sitk.ReadImage(os.path.join("..", "MuscleMap_segs", file))
    gt_image = sitk.ReadImage(gt_name)
    segment_image.CopyInformation(gt_image)

    gt = sitk.Cast(gt_image == 8, sitk.sitkUInt8)
    pred = sitk.Cast(segment_image == 7142, sitk.sitkUInt8)

    gt_arr = sitk.GetArrayFromImage(gt).astype(float)
    pred_arr = sitk.GetArrayFromImage(pred).astype(float)

    dice_filter = sitk.LabelOverlapMeasuresImageFilter()
    dice_filter.Execute(gt, pred)
    right_sart_dice_lower = dice_filter.GetDiceCoefficient()
    right_JaccardCoeffi = dice_filter.GetJaccardCoefficient()
    right_VolumeSimilar = dice_filter.GetVolumeSimilarity()
    right_FalseNegative = dice_filter.GetFalseNegativeError()
    right_FalsePositive = dice_filter.GetFalsePositiveError()

    hd_filter = sitk.HausdorffDistanceImageFilter()
    hd_filter.Execute(gt, pred)
    right_sart_hd_lower = hd_filter.GetHausdorffDistance()

    bce = binary_cross_entropy(gt_arr, pred_arr)
    biou = boundary_iou_3d(BOUNDARY_DISTANCE, gt_arr, pred_arr)

    results_r_sart.append({
        "image": gt_name,
        "pred_label": file,
        "R_sartorius_lower_dice:": right_sart_dice_lower,
        "R_sartorius_lower_Hausdorff:": right_sart_hd_lower,
        "R_sartorius_jaccard": right_JaccardCoeffi,
        "R_sartorius_volume_similarity": right_VolumeSimilar,
        "R_sartorius_falseNegative": right_FalseNegative,
        "R_sartorius_falsePostivie": right_FalsePositive,
        "R_sartorius_binary_cross_entropy": bce,
        "R_sartorius_boundary_iou_3d": biou,
    })

df_r_sart = pd.DataFrame(results_r_sart)
df_r_sart.to_csv('../MuscleMap_results_WB/df_r_sart_NEW.csv')
df_r_sart
# Out:
# HV001_1_FATFRACTION_stack1_dseg.nii.gz
# HV001_1/SegmentationMasks/combined_gt_stack1.mha
# HV001_1_FATFRACTION_stack2_dseg.nii.gz
# HV001_1/SegmentationMasks/combined_gt_stack2.mha
# HV001_2_FATFRACTION_stack1_dseg.nii.gz
# HV001_2/SegmentationMasks/combined_gt_stack1.mha
# HV001_2_FATFRACTION_stack2_dseg.nii.gz
# HV001_2/SegmentationMasks/combined_gt_stack2.mha
# HV001_3_FATFRACTION_stack1_dseg.nii.gz
# HV001_3/SegmentationMasks/combined_gt_stack1.mha
# HV001_3_FATFRACTION_stack2_dseg.nii.gz
# HV001_3/SegmentationMasks/combined_gt_stack2.mha
# HV002_1_FATFRACTION_stack1_dseg.nii.gz
# HV002_1/SegmentationMasks/combined_gt_stack1.mha
# HV002_1_FATFRACTION_stack2_dseg.nii.gz
# HV002_1/SegmentationMasks/combined_gt_stack2.mha
# HV002_2_FATFRACTION_stack1_dseg.nii.gz
# HV002_2/SegmentationMasks/combined_gt_stack1.mha
# HV002_2_FATFRACTION_stack2_dseg.nii.gz
# HV002_2/SegmentationMasks/combined_gt_stack2.mha
# HV002_3_FATFRACTION_stack1_dseg.nii.gz
# HV002_3/SegmentationMasks/combined_gt_stack1.mha
# HV002_3_FATFRACTION_stack2_dseg.nii.gz
# HV002_3/SegmentationMasks/combined_gt_stack2.mha
# HV003_1_FATFRACTION_stack1_dseg.nii.gz
# HV003_1/SegmentationMasks/combined_gt_stack1.mha
# HV003_1_FATFRACTION_stack2_dseg.nii.gz
# HV003_1/SegmentationMasks/combined_gt_stack2.mha
# HV003_2_FATFRACTION_stack1_dseg.nii.gz
# HV003_2/SegmentationMasks/combined_gt_stack1.mha
# HV003_2_FATFRACTION_stack2_dseg.nii.gz
# HV003_2/SegmentationMasks/combined_gt_stack2.mha
# HV003_3_FATFRACTION_stack1_dseg.nii.gz
# HV003_3/SegmentationMasks/combined_gt_stack1.mha
# HV003_3_FATFRACTION_stack2_dseg.nii.gz
# HV003_3/SegmentationMasks/combined_gt_stack2.mha
# HV004_1_FATFRACTION_stack1_dseg.nii.gz
# HV004_1/SegmentationMasks/combined_gt_stack1.mha
# HV004_1_FATFRACTION_stack2_dseg.nii.gz
# HV004_1/SegmentationMasks/combined_gt_stack2.mha
# HV005_1_FATFRACTION_stack1_dseg.nii.gz
# HV005_1/SegmentationMasks/combined_gt_stack1.mha
# HV005_1_FATFRACTION_stack2_dseg.nii.gz
# HV005_1/SegmentationMasks/combined_gt_stack2.mha
# HV006_1_FATFRACTION_stack1_dseg.nii.gz
# HV006_1/SegmentationMasks/combined_gt_stack1.mha
# HV006_1_FATFRACTION_stack2_dseg.nii.gz
# HV006_1/SegmentationMasks/combined_gt_stack2.mha
# HV007_1_FATFRACTION_stack1_dseg.nii.gz
# HV007_1/SegmentationMasks/combined_gt_stack1.mha
# HV007_1_FATFRACTION_stack2_dseg.nii.gz
# HV007_1/SegmentationMasks/combined_gt_stack2.mha
# HV008_1_FATFRACTION_stack1_dseg.nii.gz
# HV008_1/SegmentationMasks/combined_gt_stack1.mha
# HV008_1_FATFRACTION_stack2_dseg.nii.gz
# HV008_1/SegmentationMasks/combined_gt_stack2.mha
# HV009_1_FATFRACTION_stack1_dseg.nii.gz
# HV009_1/SegmentationMasks/combined_gt_stack1.mha
# HV009_1_FATFRACTION_stack2_dseg.nii.gz
# HV009_1/SegmentationMasks/combined_gt_stack2.mha
# HV010_1_FATFRACTION_stack1_dseg.nii.gz
# HV010_1/SegmentationMasks/combined_gt_stack1.mha
# HV010_1_FATFRACTION_stack2_dseg.nii.gz
# HV010_1/SegmentationMasks/combined_gt_stack2.mha
# HV011_1_FATFRACTION_stack1_dseg.nii.gz
# HV011_1/SegmentationMasks/combined_gt_stack1.mha
# HV011_1_FATFRACTION_stack2_dseg.nii.gz
# HV011_1/SegmentationMasks/combined_gt_stack2.mha
# HV012_1_FATFRACTION_stack1_dseg.nii.gz
# HV012_1/SegmentationMasks/combined_gt_stack1.mha
# HV012_1_FATFRACTION_stack2_dseg.nii.gz
# HV012_1/SegmentationMasks/combined_gt_stack2.mha
# HV013_1_FATFRACTION_stack1_dseg.nii.gz
# HV013_1/SegmentationMasks/combined_gt_stack1.mha
# HV013_1_FATFRACTION_stack2_dseg.nii.gz
# HV013_1/SegmentationMasks/combined_gt_stack2.mha
# HV014_1_FATFRACTION_stack1_dseg.nii.gz
# HV014_1/SegmentationMasks/combined_gt_stack1.mha
# HV014_1_FATFRACTION_stack2_dseg.nii.gz
# HV014_1/SegmentationMasks/combined_gt_stack2.mha
# HV015_1_FATFRACTION_stack1_dseg.nii.gz
# HV015_1/SegmentationMasks/combined_gt_stack1.mha
# HV015_1_FATFRACTION_stack2_dseg.nii.gz
# HV015_1/SegmentationMasks/combined_gt_stack2.mha
# P001_1_FATFRACTION_stack1_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack1.mha
# P001_1_FATFRACTION_stack2_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack2.mha
# P001_1_FATFRACTION_stack3_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack3.mha
# P002_1_FATFRACTION_stack1_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack1.mha
# P002_1_FATFRACTION_stack2_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack2.mha
# P002_1_FATFRACTION_stack3_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack3.mha
# P003_1_FATFRACTION_stack1_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack1.mha
# P003_1_FATFRACTION_stack2_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack2.mha
# P003_1_FATFRACTION_stack3_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack3.mha
# P004_1_FATFRACTION_stack1_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack1.mha
# P004_1_FATFRACTION_stack2_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack2.mha
# P004_1_FATFRACTION_stack3_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack3.mha
#                                                image  \
# 0   HV001_1/SegmentationMasks/combined_gt_stack1.mha
# 1   HV001_1/SegmentationMasks/combined_gt_stack2.mha
# 2   HV001_2/SegmentationMasks/combined_gt_stack1.mha
# 3   HV001_2/SegmentationMasks/combined_gt_stack2.mha
# 4   HV001_3/SegmentationMasks/combined_gt_stack1.mha
# 5   HV001_3/SegmentationMasks/combined_gt_stack2.mha
# 6   HV002_1/SegmentationMasks/combined_gt_stack1.mha
# 7   HV002_1/SegmentationMasks/combined_gt_stack2.mha
# 8   HV002_2/SegmentationMasks/combined_gt_stack1.mha
# 9   HV002_2/SegmentationMasks/combined_gt_stack2.mha
# 10  HV002_3/SegmentationMasks/combined_gt_stack1.mha
# 11  HV002_3/SegmentationMasks/combined_gt_stack2.mha
# 12  HV003_1/SegmentationMasks/combined_gt_stack1.mha
# 13  HV003_1/SegmentationMasks/combined_gt_stack2.mha
# 14  HV003_2/SegmentationMasks/combined_gt_stack1.mha
# 15  HV003_2/SegmentationMasks/combined_gt_stack2.mha
# 16  HV003_3/SegmentationMasks/combined_gt_stack1.mha
# 17  HV003_3/SegmentationMasks/combined_gt_stack2.mha
# 18  HV004_1/SegmentationMasks/combined_gt_stack1.mha
# 19  HV004_1/SegmentationMasks/combined_gt_stack2.mha
# 20  HV005_1/SegmentationMasks/combined_gt_stack1.mha
# 21  HV005_1/SegmentationMasks/combined_gt_stack2.mha
# 22  HV006_1/SegmentationMasks/combined_gt_stack1.mha
# 23  HV006_1/SegmentationMasks/combined_gt_stack2.mha
# 24  HV007_1/SegmentationMasks/combined_gt_stack1.mha
# 25  HV007_1/SegmentationMasks/combined_gt_stack2.mha
# 26  HV008_1/SegmentationMasks/combined_gt_stack1.mha
# 27  HV008_1/SegmentationMasks/combined_gt_stack2.mha
# 28  HV009_1/SegmentationMasks/combined_gt_stack1.mha
# 29  HV009_1/SegmentationMasks/combined_gt_stack2.mha
# 30  HV010_1/SegmentationMasks/combined_gt_stack1.mha
# 31  HV010_1/SegmentationMasks/combined_gt_stack2.mha
# 32  HV011_1/SegmentationMasks/combined_gt_stack1.mha
# 33  HV011_1/SegmentationMasks/combined_gt_stack2.mha
# 34  HV012_1/SegmentationMasks/combined_gt_stack1.mha
# 35  HV012_1/SegmentationMasks/combined_gt_stack2.mha
# 36  HV013_1/SegmentationMasks/combined_gt_stack1.mha
# 37  HV013_1/SegmentationMasks/combined_gt_stack2.mha
# 38  HV014_1/SegmentationMasks/combined_gt_stack1.mha
# 39  HV014_1/SegmentationMasks/combined_gt_stack2.mha
# 40  HV015_1/SegmentationMasks/combined_gt_stack1.mha
# 41  HV015_1/SegmentationMasks/combined_gt_stack2.mha
# 42   P001_1/SegmentationMasks/combined_gt_stack1.mha
# 43   P001_1/SegmentationMasks/combined_gt_stack2.mha
# 44   P001_1/SegmentationMasks/combined_gt_stack3.mha
# 45   P002_1/SegmentationMasks/combined_gt_stack1.mha
# 46   P002_1/SegmentationMasks/combined_gt_stack2.mha
# 47   P002_1/SegmentationMasks/combined_gt_stack3.mha
# 48   P003_1/SegmentationMasks/combined_gt_stack1.mha
# 49   P003_1/SegmentationMasks/combined_gt_stack2.mha
# 50   P003_1/SegmentationMasks/combined_gt_stack3.mha
# 51   P004_1/SegmentationMasks/combined_gt_stack1.mha
# 52   P004_1/SegmentationMasks/combined_gt_stack2.mha
# 53   P004_1/SegmentationMasks/combined_gt_stack3.mha
#
#                                 pred_label  R_sartorius_lower_dice:  \
# 0   HV001_1_FATFRACTION_stack1_dseg.nii.gz                 0.756179
# 1   HV001_1_FATFRACTION_stack2_dseg.nii.gz                 0.798659
# 2   HV001_2_FATFRACTION_stack1_dseg.nii.gz                 0.796968
# 3   HV001_2_FATFRACTION_stack2_dseg.nii.gz                 0.880188
# 4   HV001_3_FATFRACTION_stack1_dseg.nii.gz                 0.853190
# 5   HV001_3_FATFRACTION_stack2_dseg.nii.gz                 0.884641
# 6   HV002_1_FATFRACTION_stack1_dseg.nii.gz                 0.852560
# 7   HV002_1_FATFRACTION_stack2_dseg.nii.gz                 0.876557
# 8   HV002_2_FATFRACTION_stack1_dseg.nii.gz                 0.835869
# 9   HV002_2_FATFRACTION_stack2_dseg.nii.gz                 0.893196
# 10  HV002_3_FATFRACTION_stack1_dseg.nii.gz                 0.859762
# 11  HV002_3_FATFRACTION_stack2_dseg.nii.gz                 0.888236
# 12  HV003_1_FATFRACTION_stack1_dseg.nii.gz                 0.865683
# 13  HV003_1_FATFRACTION_stack2_dseg.nii.gz                 0.900111
# 14  HV003_2_FATFRACTION_stack1_dseg.nii.gz                 0.859566
# 15  HV003_2_FATFRACTION_stack2_dseg.nii.gz                 0.901110
# 16  HV003_3_FATFRACTION_stack1_dseg.nii.gz                 0.834028
# 17  HV003_3_FATFRACTION_stack2_dseg.nii.gz                 0.879453
# 18  HV004_1_FATFRACTION_stack1_dseg.nii.gz                 0.825795
# 19  HV004_1_FATFRACTION_stack2_dseg.nii.gz                 0.885899
# 20  HV005_1_FATFRACTION_stack1_dseg.nii.gz                 0.788150
# 21  HV005_1_FATFRACTION_stack2_dseg.nii.gz                 0.849681
# 22  HV006_1_FATFRACTION_stack1_dseg.nii.gz                 0.855524
# 23  HV006_1_FATFRACTION_stack2_dseg.nii.gz                 0.893807
# 24  HV007_1_FATFRACTION_stack1_dseg.nii.gz                 0.805580
# 25  HV007_1_FATFRACTION_stack2_dseg.nii.gz                 0.816939
# 26  HV008_1_FATFRACTION_stack1_dseg.nii.gz                 0.841483
# 27  HV008_1_FATFRACTION_stack2_dseg.nii.gz                 0.880698
# 28  HV009_1_FATFRACTION_stack1_dseg.nii.gz                 0.845511
# 29  HV009_1_FATFRACTION_stack2_dseg.nii.gz                 0.878385
# 30  HV010_1_FATFRACTION_stack1_dseg.nii.gz                 0.775595
# 31  HV010_1_FATFRACTION_stack2_dseg.nii.gz                 0.830711
# 32  HV011_1_FATFRACTION_stack1_dseg.nii.gz                 0.765967
# 33  HV011_1_FATFRACTION_stack2_dseg.nii.gz                 0.833767
# 34  HV012_1_FATFRACTION_stack1_dseg.nii.gz                 0.751665
# 35  HV012_1_FATFRACTION_stack2_dseg.nii.gz                 0.607805
# 36  HV013_1_FATFRACTION_stack1_dseg.nii.gz                 0.732107
# 37  HV013_1_FATFRACTION_stack2_dseg.nii.gz                 0.742339
# 38  HV014_1_FATFRACTION_stack1_dseg.nii.gz                 0.539231
# 39  HV014_1_FATFRACTION_stack2_dseg.nii.gz                 0.000000
# 40  HV015_1_FATFRACTION_stack1_dseg.nii.gz                 0.702382
# 41  HV015_1_FATFRACTION_stack2_dseg.nii.gz                 0.738219
# 42   P001_1_FATFRACTION_stack1_dseg.nii.gz                 0.857014
# 43   P001_1_FATFRACTION_stack2_dseg.nii.gz                 0.890653
# 44   P001_1_FATFRACTION_stack3_dseg.nii.gz                 0.789062
# 45   P002_1_FATFRACTION_stack1_dseg.nii.gz                 0.816122
# 46   P002_1_FATFRACTION_stack2_dseg.nii.gz                 0.771764
# 47   P002_1_FATFRACTION_stack3_dseg.nii.gz                 0.580210
# 48   P003_1_FATFRACTION_stack1_dseg.nii.gz                 0.759643
# 49   P003_1_FATFRACTION_stack2_dseg.nii.gz                 0.781868
# 50   P003_1_FATFRACTION_stack3_dseg.nii.gz                 0.754765
# 51   P004_1_FATFRACTION_stack1_dseg.nii.gz                 0.800377
# 52   P004_1_FATFRACTION_stack2_dseg.nii.gz                 0.807495
# 53   P004_1_FATFRACTION_stack3_dseg.nii.gz                 0.649907
#
#     R_sartorius_lower_Hausdorff:  R_sartorius_jaccard  \
# 0                      40.000000             0.607949
# 1                      20.049938             0.664807
# 2                      44.000000             0.662466
# 3                      20.000000             0.786015
# 4                      36.000000             0.743968
# 5                      20.024984             0.793144
# 6                      14.000000             0.743011
# 7                      24.269322             0.780241
# 8                      16.401219             0.718019
# 9                      20.024984             0.807004
# 10                     12.369317             0.754020
# 11                     16.155494             0.798943
# 12                     36.345564             0.763175
# 13                     20.000000             0.818365
# 14                     28.231188             0.753718
# 15                     20.000000             0.820019
# 16                     32.264532             0.715307
# 17                     20.000000             0.784842
# 18                     20.396078             0.703281
# 19                     16.000000             0.795169
# 20                     21.771541             0.650369
# 21                     24.000000             0.738648
# 22                     36.221541             0.747524
# 23                      8.306624             0.808003
# 24                     40.311289             0.674453
# 25                     16.062378             0.690530
# 26                     16.522712             0.726345
# 27                      8.062258             0.786828
# 28                     32.893768             0.732368
# 29                      9.165151             0.783143
# 30                     36.013886             0.633446
# 31                      8.000000             0.710441
# 32                     40.012498             0.620702
# 33                      8.000000             0.714923
# 34                     11.180340             0.602133
# 35                      8.485281             0.436580
# 36                     24.083189             0.577420
# 37                     24.535688             0.590253
# 38                     24.413111             0.369142
# 39                     85.005882             0.000000
# 40                     13.928388             0.541286
# 41                     12.206556             0.585061
# 42                      4.358899             0.749803
# 43                      5.744563             0.802862
# 44                      8.944272             0.651612
# 45                      4.358899             0.689364
# 46                      4.472136             0.628351
# 47                     13.453624             0.408659
# 48                      4.242641             0.612439
# 49                      4.898979             0.641859
# 50                      5.656854             0.606123
# 51                      8.485281             0.667190
# 52                      4.472136             0.677142
# 53                     21.213203             0.481380
#
#     R_sartorius_volume_similarity  R_sartorius_falseNegative  \
# 0                       -0.257952                   0.330208
# 1                       -0.237944                   0.286256
# 2                       -0.190659                   0.272395
# 3                       -0.042271                   0.138030
# 4                       -0.090293                   0.183665
# 5                       -0.005500                   0.117785
# 6                        0.097003                   0.103982
# 7                        0.024563                   0.112544
# 8                       -0.084465                   0.198002
# 9                       -0.017976                   0.114761
# 10                      -0.044652                   0.159014
# 11                      -0.056194                   0.136039
# 12                      -0.009392                   0.138363
# 13                      -0.042149                   0.118467
# 14                      -0.116488                   0.187743
# 15                      -0.046418                   0.119329
# 16                      -0.220254                   0.248709
# 17                      -0.150728                   0.182182
# 18                      -0.154293                   0.233349
# 19                      -0.047078                   0.134475
# 20                      -0.169053                   0.273278
# 21                      -0.107680                   0.193728
# 22                      -0.128950                   0.196295
# 23                      -0.061974                   0.133056
# 24                      -0.188118                   0.263678
# 25                      -0.219576                   0.263878
# 26                      -0.111441                   0.202930
# 27                      -0.088933                   0.156797
# 28                      -0.063342                   0.180445
# 29                      -0.048561                   0.142437
# 30                      -0.254223                   0.311874
# 31                      -0.199414                   0.244607
# 32                      -0.264906                   0.323622
# 33                      -0.176300                   0.233776
# 34                      -0.462672                   0.389554
# 35                      -0.761405                   0.559786
# 36                      -0.491456                   0.412306
# 37                      -0.493326                   0.404539
# 38                      -0.911655                   0.629605
# 39                      -1.436066                   1.000000
# 40                      -0.538272                   0.446567
# 41                      -0.406975                   0.386600
# 42                      -0.200300                   0.221003
# 43                      -0.087433                   0.146652
# 44                      -0.191490                   0.279885
# 45                      -0.348497                   0.304983
# 46                      -0.438750                   0.367082
# 47                      -0.838407                   0.591172
# 48                      -0.462986                   0.383153
# 49                      -0.336390                   0.330704
# 50                      -0.488098                   0.393300
# 51                      -0.341012                   0.316213
# 52                      -0.337714                   0.309158
# 53                      -0.631092                   0.505979
#
#     R_sartorius_falsePostivie  R_sartorius_binary_cross_entropy  \
# 0                1.154514e-04                          0.007893
# 1                8.388670e-05                          0.006603
# 2                1.146023e-04                          0.006956
# 3                1.079993e-04                          0.004223
# 4                1.146720e-04                          0.005332
# 5                1.267127e-04                          0.004180
# 6                2.625225e-04                          0.006360
# 7                1.544119e-04                          0.004522
# 8                1.477354e-04                          0.006404
# 9                1.162597e-04                          0.004087
# 10               1.456546e-04                          0.005577
# 11               9.228467e-05                          0.003970
# 12               1.586456e-04                          0.005293
# 13               9.248706e-05                          0.003774
# 14               9.735227e-05                          0.005356
# 15               8.904939e-05                          0.003747
# 16               6.214879e-05                          0.005947
# 17               5.059067e-05                          0.004346
# 18               9.924741e-05                          0.005736
# 19               8.908096e-05                          0.003614
# 20               1.097678e-04                          0.005882
# 21               8.544073e-05                          0.004287
# 22               7.485399e-05                          0.004353
# 23               7.675847e-05                          0.003490
# 24               8.009588e-05                          0.004998
# 25               5.921711e-05                          0.004765
# 26               9.609870e-05                          0.004772
# 27               6.255457e-05                          0.003212
# 28               1.408678e-04                          0.005705
# 29               1.127219e-04                          0.004535
# 30               3.848005e-05                          0.002860
# 31               3.440842e-05                          0.002697
# 32               3.997971e-05                          0.002968
# 33               3.902239e-05                          0.002677
# 34               1.191504e-05                          0.005606
# 35               1.142439e-05                          0.012551
# 36               2.016171e-05                          0.007846
# 37               1.162243e-05                          0.008766
# 38               4.072340e-06                          0.012226
# 39               1.665379e-04                          0.019020
# 40               3.338292e-05                          0.011228
# 41               6.974313e-05                          0.010082
# 42               9.087424e-05                          0.009756
# 43               1.496371e-04                          0.008018
# 44               1.867427e-04                          0.011004
# 45               9.930224e-06                          0.006106
# 46               9.421786e-06                          0.007813
# 47               5.092527e-07                          0.011730
# 48               1.031444e-05                          0.009004
# 49               7.247476e-05                          0.010188
# 50               1.655908e-06                          0.011022
# 51               4.330850e-05                          0.009555
# 52               2.852323e-05                          0.007475
# 53               2.851400e-05                          0.009305
#
#     R_sartorius_boundary_iou_3d
# 0                      0.442209
# 1                      0.561325
# 2                      0.515923
# 3                      0.691655
# 4                      0.601977
# 5                      0.689993
# 6                      0.604943
# 7                      0.630907
# 8                      0.588234
# 9                      0.671580
# 10                     0.616056
# 11                     0.665915
# 12                     0.608412
# 13                     0.686784
# 14                     0.585879
# 15                     0.687379
# 16                     0.530536
# 17                     0.645664
# 18                     0.570541
# 19                     0.679727
# 20                     0.550015
# 21                     0.617435
# 22                     0.601088
# 23                     0.693184
# 24                     0.559338
# 25                     0.555104
# 26                     0.614675
# 27                     0.672956
# 28                     0.589754
# 29                     0.657754
# 30                     0.563185
# 31                     0.691049
# 32                     0.545892
# 33                     0.697250
# 34                     0.501194
# 35                     0.343059
# 36                     0.466300
# 37                     0.484048
# 38                     0.337651
# 39                     0.000000
# 40                     0.414592
# 41                     0.500022
# 42                     0.643050
# 43                     0.668631
# 44                     0.451876
# 45                     0.534324
# 46                     0.519882
# 47                     0.265331
# 48                     0.539277
# 49                     0.526208
# 50                     0.370109
# 51                     0.555111
# 52                     0.583056
# 53                     0.357881

# %% [markdown]
# ## Left sartorius

# %%
results_l_sart = []
for file in os.listdir(os.path.join("..", "MuscleMap_segs")):
    print(file)
    if file[0] == 'H':
        gt_name = file[:7] + "/SegmentationMasks/combined_gt_stack" + file[-13] + ".mha"
    else:
        gt_name = file[:6] + "/SegmentationMasks/combined_gt_stack" + file[-13] + ".mha"
    print(gt_name)

    segment_image = sitk.ReadImage(os.path.join("..", "MuscleMap_segs", file))
    gt_image = sitk.ReadImage(gt_name)
    segment_image.CopyInformation(gt_image)

    gt = sitk.Cast(gt_image == 4, sitk.sitkUInt8)
    pred = sitk.Cast(segment_image == 7141, sitk.sitkUInt8)

    gt_arr = sitk.GetArrayFromImage(gt).astype(float)
    pred_arr = sitk.GetArrayFromImage(pred).astype(float)

    dice_filter = sitk.LabelOverlapMeasuresImageFilter()
    dice_filter.Execute(gt, pred)
    left_sart_dice_lower = dice_filter.GetDiceCoefficient()
    left_JaccardCoeffi = dice_filter.GetJaccardCoefficient()
    left_VolumeSimilar = dice_filter.GetVolumeSimilarity()
    left_FalseNegative = dice_filter.GetFalseNegativeError()
    left_FalsePositive = dice_filter.GetFalsePositiveError()

    hd_filter = sitk.HausdorffDistanceImageFilter()
    hd_filter.Execute(gt, pred)
    left_sart_hd_lower = hd_filter.GetHausdorffDistance()

    bce = binary_cross_entropy(gt_arr, pred_arr)
    biou = boundary_iou_3d(BOUNDARY_DISTANCE, gt_arr, pred_arr)

    results_l_sart.append({
        "image": gt_name,
        "pred_label": file,
        "L_sartorius_lower_dice:": left_sart_dice_lower,
        "L_sartorius_lower_Hausdorff:": left_sart_hd_lower,
        "L_sartorius_jaccard": left_JaccardCoeffi,
        "L_sartorius_volume_similarity": left_VolumeSimilar,
        "L_sartorius_falseNegative": left_FalseNegative,
        "L_sartorius_falsePostivie": left_FalsePositive,
        "L_sartorius_binary_cross_entropy": bce,
        "L_sartorius_boundary_iou_3d": biou,
    })

df_l_sart = pd.DataFrame(results_l_sart)
df_l_sart.to_csv('../MuscleMap_results_WB/df_l_sart_NEW.csv')
df_l_sart
# Out:
# HV001_1_FATFRACTION_stack1_dseg.nii.gz
# HV001_1/SegmentationMasks/combined_gt_stack1.mha
# HV001_1_FATFRACTION_stack2_dseg.nii.gz
# HV001_1/SegmentationMasks/combined_gt_stack2.mha
# HV001_2_FATFRACTION_stack1_dseg.nii.gz
# HV001_2/SegmentationMasks/combined_gt_stack1.mha
# HV001_2_FATFRACTION_stack2_dseg.nii.gz
# HV001_2/SegmentationMasks/combined_gt_stack2.mha
# HV001_3_FATFRACTION_stack1_dseg.nii.gz
# HV001_3/SegmentationMasks/combined_gt_stack1.mha
# HV001_3_FATFRACTION_stack2_dseg.nii.gz
# HV001_3/SegmentationMasks/combined_gt_stack2.mha
# HV002_1_FATFRACTION_stack1_dseg.nii.gz
# HV002_1/SegmentationMasks/combined_gt_stack1.mha
# HV002_1_FATFRACTION_stack2_dseg.nii.gz
# HV002_1/SegmentationMasks/combined_gt_stack2.mha
# HV002_2_FATFRACTION_stack1_dseg.nii.gz
# HV002_2/SegmentationMasks/combined_gt_stack1.mha
# HV002_2_FATFRACTION_stack2_dseg.nii.gz
# HV002_2/SegmentationMasks/combined_gt_stack2.mha
# HV002_3_FATFRACTION_stack1_dseg.nii.gz
# HV002_3/SegmentationMasks/combined_gt_stack1.mha
# HV002_3_FATFRACTION_stack2_dseg.nii.gz
# HV002_3/SegmentationMasks/combined_gt_stack2.mha
# HV003_1_FATFRACTION_stack1_dseg.nii.gz
# HV003_1/SegmentationMasks/combined_gt_stack1.mha
# HV003_1_FATFRACTION_stack2_dseg.nii.gz
# HV003_1/SegmentationMasks/combined_gt_stack2.mha
# HV003_2_FATFRACTION_stack1_dseg.nii.gz
# HV003_2/SegmentationMasks/combined_gt_stack1.mha
# HV003_2_FATFRACTION_stack2_dseg.nii.gz
# HV003_2/SegmentationMasks/combined_gt_stack2.mha
# HV003_3_FATFRACTION_stack1_dseg.nii.gz
# HV003_3/SegmentationMasks/combined_gt_stack1.mha
# HV003_3_FATFRACTION_stack2_dseg.nii.gz
# HV003_3/SegmentationMasks/combined_gt_stack2.mha
# HV004_1_FATFRACTION_stack1_dseg.nii.gz
# HV004_1/SegmentationMasks/combined_gt_stack1.mha
# HV004_1_FATFRACTION_stack2_dseg.nii.gz
# HV004_1/SegmentationMasks/combined_gt_stack2.mha
# HV005_1_FATFRACTION_stack1_dseg.nii.gz
# HV005_1/SegmentationMasks/combined_gt_stack1.mha
# HV005_1_FATFRACTION_stack2_dseg.nii.gz
# HV005_1/SegmentationMasks/combined_gt_stack2.mha
# HV006_1_FATFRACTION_stack1_dseg.nii.gz
# HV006_1/SegmentationMasks/combined_gt_stack1.mha
# HV006_1_FATFRACTION_stack2_dseg.nii.gz
# HV006_1/SegmentationMasks/combined_gt_stack2.mha
# HV007_1_FATFRACTION_stack1_dseg.nii.gz
# HV007_1/SegmentationMasks/combined_gt_stack1.mha
# HV007_1_FATFRACTION_stack2_dseg.nii.gz
# HV007_1/SegmentationMasks/combined_gt_stack2.mha
# HV008_1_FATFRACTION_stack1_dseg.nii.gz
# HV008_1/SegmentationMasks/combined_gt_stack1.mha
# HV008_1_FATFRACTION_stack2_dseg.nii.gz
# HV008_1/SegmentationMasks/combined_gt_stack2.mha
# HV009_1_FATFRACTION_stack1_dseg.nii.gz
# HV009_1/SegmentationMasks/combined_gt_stack1.mha
# HV009_1_FATFRACTION_stack2_dseg.nii.gz
# HV009_1/SegmentationMasks/combined_gt_stack2.mha
# HV010_1_FATFRACTION_stack1_dseg.nii.gz
# HV010_1/SegmentationMasks/combined_gt_stack1.mha
# HV010_1_FATFRACTION_stack2_dseg.nii.gz
# HV010_1/SegmentationMasks/combined_gt_stack2.mha
# HV011_1_FATFRACTION_stack1_dseg.nii.gz
# HV011_1/SegmentationMasks/combined_gt_stack1.mha
# HV011_1_FATFRACTION_stack2_dseg.nii.gz
# HV011_1/SegmentationMasks/combined_gt_stack2.mha
# HV012_1_FATFRACTION_stack1_dseg.nii.gz
# HV012_1/SegmentationMasks/combined_gt_stack1.mha
# HV012_1_FATFRACTION_stack2_dseg.nii.gz
# HV012_1/SegmentationMasks/combined_gt_stack2.mha
# HV013_1_FATFRACTION_stack1_dseg.nii.gz
# HV013_1/SegmentationMasks/combined_gt_stack1.mha
# HV013_1_FATFRACTION_stack2_dseg.nii.gz
# HV013_1/SegmentationMasks/combined_gt_stack2.mha
# HV014_1_FATFRACTION_stack1_dseg.nii.gz
# HV014_1/SegmentationMasks/combined_gt_stack1.mha
# HV014_1_FATFRACTION_stack2_dseg.nii.gz
# HV014_1/SegmentationMasks/combined_gt_stack2.mha
# HV015_1_FATFRACTION_stack1_dseg.nii.gz
# HV015_1/SegmentationMasks/combined_gt_stack1.mha
# HV015_1_FATFRACTION_stack2_dseg.nii.gz
# HV015_1/SegmentationMasks/combined_gt_stack2.mha
# P001_1_FATFRACTION_stack1_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack1.mha
# P001_1_FATFRACTION_stack2_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack2.mha
# P001_1_FATFRACTION_stack3_dseg.nii.gz
# P001_1/SegmentationMasks/combined_gt_stack3.mha
# P002_1_FATFRACTION_stack1_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack1.mha
# P002_1_FATFRACTION_stack2_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack2.mha
# P002_1_FATFRACTION_stack3_dseg.nii.gz
# P002_1/SegmentationMasks/combined_gt_stack3.mha
# P003_1_FATFRACTION_stack1_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack1.mha
# P003_1_FATFRACTION_stack2_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack2.mha
# P003_1_FATFRACTION_stack3_dseg.nii.gz
# P003_1/SegmentationMasks/combined_gt_stack3.mha
# P004_1_FATFRACTION_stack1_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack1.mha
# P004_1_FATFRACTION_stack2_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack2.mha
# P004_1_FATFRACTION_stack3_dseg.nii.gz
# P004_1/SegmentationMasks/combined_gt_stack3.mha
#                                                image  \
# 0   HV001_1/SegmentationMasks/combined_gt_stack1.mha
# 1   HV001_1/SegmentationMasks/combined_gt_stack2.mha
# 2   HV001_2/SegmentationMasks/combined_gt_stack1.mha
# 3   HV001_2/SegmentationMasks/combined_gt_stack2.mha
# 4   HV001_3/SegmentationMasks/combined_gt_stack1.mha
# 5   HV001_3/SegmentationMasks/combined_gt_stack2.mha
# 6   HV002_1/SegmentationMasks/combined_gt_stack1.mha
# 7   HV002_1/SegmentationMasks/combined_gt_stack2.mha
# 8   HV002_2/SegmentationMasks/combined_gt_stack1.mha
# 9   HV002_2/SegmentationMasks/combined_gt_stack2.mha
# 10  HV002_3/SegmentationMasks/combined_gt_stack1.mha
# 11  HV002_3/SegmentationMasks/combined_gt_stack2.mha
# 12  HV003_1/SegmentationMasks/combined_gt_stack1.mha
# 13  HV003_1/SegmentationMasks/combined_gt_stack2.mha
# 14  HV003_2/SegmentationMasks/combined_gt_stack1.mha
# 15  HV003_2/SegmentationMasks/combined_gt_stack2.mha
# 16  HV003_3/SegmentationMasks/combined_gt_stack1.mha
# 17  HV003_3/SegmentationMasks/combined_gt_stack2.mha
# 18  HV004_1/SegmentationMasks/combined_gt_stack1.mha
# 19  HV004_1/SegmentationMasks/combined_gt_stack2.mha
# 20  HV005_1/SegmentationMasks/combined_gt_stack1.mha
# 21  HV005_1/SegmentationMasks/combined_gt_stack2.mha
# 22  HV006_1/SegmentationMasks/combined_gt_stack1.mha
# 23  HV006_1/SegmentationMasks/combined_gt_stack2.mha
# 24  HV007_1/SegmentationMasks/combined_gt_stack1.mha
# 25  HV007_1/SegmentationMasks/combined_gt_stack2.mha
# 26  HV008_1/SegmentationMasks/combined_gt_stack1.mha
# 27  HV008_1/SegmentationMasks/combined_gt_stack2.mha
# 28  HV009_1/SegmentationMasks/combined_gt_stack1.mha
# 29  HV009_1/SegmentationMasks/combined_gt_stack2.mha
# 30  HV010_1/SegmentationMasks/combined_gt_stack1.mha
# 31  HV010_1/SegmentationMasks/combined_gt_stack2.mha
# 32  HV011_1/SegmentationMasks/combined_gt_stack1.mha
# 33  HV011_1/SegmentationMasks/combined_gt_stack2.mha
# 34  HV012_1/SegmentationMasks/combined_gt_stack1.mha
# 35  HV012_1/SegmentationMasks/combined_gt_stack2.mha
# 36  HV013_1/SegmentationMasks/combined_gt_stack1.mha
# 37  HV013_1/SegmentationMasks/combined_gt_stack2.mha
# 38  HV014_1/SegmentationMasks/combined_gt_stack1.mha
# 39  HV014_1/SegmentationMasks/combined_gt_stack2.mha
# 40  HV015_1/SegmentationMasks/combined_gt_stack1.mha
# 41  HV015_1/SegmentationMasks/combined_gt_stack2.mha
# 42   P001_1/SegmentationMasks/combined_gt_stack1.mha
# 43   P001_1/SegmentationMasks/combined_gt_stack2.mha
# 44   P001_1/SegmentationMasks/combined_gt_stack3.mha
# 45   P002_1/SegmentationMasks/combined_gt_stack1.mha
# 46   P002_1/SegmentationMasks/combined_gt_stack2.mha
# 47   P002_1/SegmentationMasks/combined_gt_stack3.mha
# 48   P003_1/SegmentationMasks/combined_gt_stack1.mha
# 49   P003_1/SegmentationMasks/combined_gt_stack2.mha
# 50   P003_1/SegmentationMasks/combined_gt_stack3.mha
# 51   P004_1/SegmentationMasks/combined_gt_stack1.mha
# 52   P004_1/SegmentationMasks/combined_gt_stack2.mha
# 53   P004_1/SegmentationMasks/combined_gt_stack3.mha
#
#                                 pred_label  L_sartorius_lower_dice:  \
# 0   HV001_1_FATFRACTION_stack1_dseg.nii.gz                 0.872514
# 1   HV001_1_FATFRACTION_stack2_dseg.nii.gz                 0.862302
# 2   HV001_2_FATFRACTION_stack1_dseg.nii.gz                 0.858329
# 3   HV001_2_FATFRACTION_stack2_dseg.nii.gz                 0.866801
# 4   HV001_3_FATFRACTION_stack1_dseg.nii.gz                 0.874369
# 5   HV001_3_FATFRACTION_stack2_dseg.nii.gz                 0.872920
# 6   HV002_1_FATFRACTION_stack1_dseg.nii.gz                 0.846887
# 7   HV002_1_FATFRACTION_stack2_dseg.nii.gz                 0.869859
# 8   HV002_2_FATFRACTION_stack1_dseg.nii.gz                 0.866017
# 9   HV002_2_FATFRACTION_stack2_dseg.nii.gz                 0.872744
# 10  HV002_3_FATFRACTION_stack1_dseg.nii.gz                 0.868631
# 11  HV002_3_FATFRACTION_stack2_dseg.nii.gz                 0.869371
# 12  HV003_1_FATFRACTION_stack1_dseg.nii.gz                 0.873400
# 13  HV003_1_FATFRACTION_stack2_dseg.nii.gz                 0.900034
# 14  HV003_2_FATFRACTION_stack1_dseg.nii.gz                 0.890174
# 15  HV003_2_FATFRACTION_stack2_dseg.nii.gz                 0.892570
# 16  HV003_3_FATFRACTION_stack1_dseg.nii.gz                 0.886477
# 17  HV003_3_FATFRACTION_stack2_dseg.nii.gz                 0.893042
# 18  HV004_1_FATFRACTION_stack1_dseg.nii.gz                 0.875426
# 19  HV004_1_FATFRACTION_stack2_dseg.nii.gz                 0.875950
# 20  HV005_1_FATFRACTION_stack1_dseg.nii.gz                 0.862586
# 21  HV005_1_FATFRACTION_stack2_dseg.nii.gz                 0.863443
# 22  HV006_1_FATFRACTION_stack1_dseg.nii.gz                 0.877771
# 23  HV006_1_FATFRACTION_stack2_dseg.nii.gz                 0.896262
# 24  HV007_1_FATFRACTION_stack1_dseg.nii.gz                 0.815854
# 25  HV007_1_FATFRACTION_stack2_dseg.nii.gz                 0.815667
# 26  HV008_1_FATFRACTION_stack1_dseg.nii.gz                 0.868249
# 27  HV008_1_FATFRACTION_stack2_dseg.nii.gz                 0.882355
# 28  HV009_1_FATFRACTION_stack1_dseg.nii.gz                 0.839489
# 29  HV009_1_FATFRACTION_stack2_dseg.nii.gz                 0.877898
# 30  HV010_1_FATFRACTION_stack1_dseg.nii.gz                 0.794563
# 31  HV010_1_FATFRACTION_stack2_dseg.nii.gz                 0.817675
# 32  HV011_1_FATFRACTION_stack1_dseg.nii.gz                 0.799628
# 33  HV011_1_FATFRACTION_stack2_dseg.nii.gz                 0.821513
# 34  HV012_1_FATFRACTION_stack1_dseg.nii.gz                 0.714561
# 35  HV012_1_FATFRACTION_stack2_dseg.nii.gz                 0.589134
# 36  HV013_1_FATFRACTION_stack1_dseg.nii.gz                 0.707515
# 37  HV013_1_FATFRACTION_stack2_dseg.nii.gz                 0.645060
# 38  HV014_1_FATFRACTION_stack1_dseg.nii.gz                 0.659603
# 39  HV014_1_FATFRACTION_stack2_dseg.nii.gz                 0.627404
# 40  HV015_1_FATFRACTION_stack1_dseg.nii.gz                 0.714859
# 41  HV015_1_FATFRACTION_stack2_dseg.nii.gz                 0.614420
# 42   P001_1_FATFRACTION_stack1_dseg.nii.gz                 0.688510
# 43   P001_1_FATFRACTION_stack2_dseg.nii.gz                 0.847974
# 44   P001_1_FATFRACTION_stack3_dseg.nii.gz                 0.800262
# 45   P002_1_FATFRACTION_stack1_dseg.nii.gz                 0.839154
# 46   P002_1_FATFRACTION_stack2_dseg.nii.gz                 0.760178
# 47   P002_1_FATFRACTION_stack3_dseg.nii.gz                 0.658846
# 48   P003_1_FATFRACTION_stack1_dseg.nii.gz                 0.803388
# 49   P003_1_FATFRACTION_stack2_dseg.nii.gz                 0.759562
# 50   P003_1_FATFRACTION_stack3_dseg.nii.gz                 0.822021
# 51   P004_1_FATFRACTION_stack1_dseg.nii.gz                 0.817219
# 52   P004_1_FATFRACTION_stack2_dseg.nii.gz                 0.820745
# 53   P004_1_FATFRACTION_stack3_dseg.nii.gz                 0.659756
#
#     L_sartorius_lower_Hausdorff:  L_sartorius_jaccard  \
# 0                      20.000000             0.773858
# 1                      44.022721             0.757935
# 2                      40.000000             0.751819
# 3                      36.000000             0.764916
# 4                      28.000000             0.776781
# 5                      32.015621             0.774496
# 6                      14.142136             0.734436
# 7                      28.071338             0.769690
# 8                      13.892444             0.763694
# 9                      24.269322             0.774220
# 10                     15.264338             0.767770
# 11                     28.017851             0.768926
# 12                     20.000000             0.775253
# 13                     28.000000             0.818237
# 14                     16.000000             0.802085
# 15                     28.000000             0.805984
# 16                     16.000000             0.796102
# 17                     28.071338             0.806754
# 18                     20.049938             0.778452
# 19                     36.027767             0.779281
# 20                     20.615528             0.758375
# 21                     24.000000             0.759700
# 22                     20.000000             0.782168
# 23                      5.830952             0.812025
# 24                     36.000000             0.688981
# 25                     20.049938             0.688714
# 26                     16.031220             0.767172
# 27                      8.062258             0.789476
# 28                     32.249031             0.723379
# 29                     20.024984             0.782369
# 30                     24.020824             0.659149
# 31                      8.000000             0.691582
# 32                     28.017851             0.666150
# 33                      8.000000             0.697092
# 34                      9.165151             0.555888
# 35                     10.049876             0.417569
# 36                      8.774964             0.547407
# 37                     24.103942             0.476080
# 38                     10.000000             0.492096
# 39                      9.000000             0.457093
# 40                     20.322401             0.556250
# 41                     17.204651             0.443439
# 42                     11.747340             0.524983
# 43                     13.892444             0.736071
# 44                     10.488088             0.667030
# 45                      3.000000             0.722881
# 46                      5.099020             0.613134
# 47                     11.180340             0.491253
# 48                      3.000000             0.671385
# 49                      5.916080             0.612333
# 50                      5.744563             0.697824
# 51                      3.605551             0.690930
# 52                      4.358899             0.695987
# 53                     17.000000             0.492266
#
#     L_sartorius_volume_similarity  L_sartorius_falseNegative  \
# 0                       -0.106311                   0.171524
# 1                       -0.139220                   0.193817
# 2                       -0.022031                   0.151023
# 3                        0.040740                   0.115175
# 4                        0.005699                   0.123132
# 5                       -0.022475                   0.136781
# 6                        0.174330                   0.072244
# 7                       -0.062181                   0.156370
# 8                        0.141338                   0.068129
# 9                       -0.028132                   0.139361
# 10                       0.158533                   0.056588
# 11                      -0.011264                   0.135498
# 12                       0.041228                   0.108217
# 13                       0.019774                   0.090979
# 14                       0.036194                   0.093419
# 15                       0.030513                   0.093601
# 16                       0.015899                   0.106419
# 17                       0.061717                   0.078523
# 18                      -0.018099                   0.132425
# 19                       0.045431                   0.103690
# 20                      -0.004586                   0.139387
# 21                      -0.039977                   0.153478
# 22                       0.126584                   0.062919
# 23                       0.046101                   0.082591
# 24                      -0.083028                   0.216665
# 25                      -0.172902                   0.249238
# 26                      -0.019199                   0.140007
# 27                      -0.031780                   0.131447
# 28                       0.153406                   0.090770
# 29                       0.068667                   0.090889
# 30                      -0.150788                   0.261143
# 31                      -0.000343                   0.182465
# 32                      -0.036770                   0.214808
# 33                      -0.012690                   0.183666
# 34                      -0.464310                   0.420072
# 35                      -0.810081                   0.580700
# 36                      -0.553374                   0.445819
# 37                      -0.705865                   0.523214
# 38                      -0.674499                   0.506746
# 39                      -0.710922                   0.537129
# 40                      -0.520168                   0.432689
# 41                      -0.768046                   0.556062
# 42                       0.347911                   0.166498
# 43                      -0.099322                   0.192145
# 44                      -0.075864                   0.228984
# 45                      -0.254108                   0.255445
# 46                      -0.468485                   0.384094
# 47                      -0.681795                   0.508653
# 48                      -0.332573                   0.311157
# 49                      -0.478412                   0.387058
# 50                      -0.307860                   0.287633
# 51                      -0.277569                   0.282377
# 52                      -0.313153                   0.290367
# 53                      -0.599535                   0.492405
#
#     L_sartorius_falsePostivie  L_sartorius_binary_cross_entropy  \
# 0                6.697327e-05                          0.003699
# 1                7.362312e-05                          0.004794
# 2                1.282232e-04                          0.004478
# 3                1.734649e-04                          0.004845
# 4                1.314666e-04                          0.004140
# 5                1.263165e-04                          0.004462
# 6                3.269826e-04                          0.006709
# 7                1.153267e-04                          0.004879
# 8                2.681355e-04                          0.005652
# 9                1.424992e-04                          0.005158
# 10               2.872478e-04                          0.005768
# 11               1.509877e-04                          0.005080
# 12               1.722070e-04                          0.004769
# 13               1.282387e-04                          0.003758
# 14               1.527359e-04                          0.004222
# 15               1.425786e-04                          0.004020
# 16               1.391559e-04                          0.004188
# 17               1.666000e-04                          0.004163
# 18               1.097021e-04                          0.003810
# 19               1.507104e-04                          0.004102
# 20               1.366493e-04                          0.004475
# 21               1.208596e-04                          0.004559
# 22               1.924673e-04                          0.004084
# 23               1.416871e-04                          0.003733
# 24               1.048397e-04                          0.004360
# 25               7.251711e-05                          0.004399
# 26               1.149869e-04                          0.003994
# 27               8.410706e-05                          0.003132
# 28               2.687375e-04                          0.005856
# 29               1.777852e-04                          0.004468
# 30               5.640903e-05                          0.002871
# 31               1.042099e-04                          0.003361
# 32               8.333538e-05                          0.002957
# 33               9.787779e-05                          0.003270
# 34               3.435266e-05                          0.005928
# 35               6.557975e-06                          0.014885
# 36               1.350679e-05                          0.008053
# 37               2.086262e-06                          0.011873
# 38               2.979959e-06                          0.010378
# 39               1.499793e-05                          0.010501
# 40               2.851305e-05                          0.010445
# 41               1.888085e-06                          0.015050
# 42               1.107966e-03                          0.022875
# 43               2.443700e-04                          0.011670
# 44               2.678698e-04                          0.010641
# 45               4.189297e-05                          0.006419
# 46               6.876900e-06                          0.009514
# 47               2.546518e-07                          0.010908
# 48               3.807549e-05                          0.007946
# 49               1.783385e-06                          0.011197
# 50               3.081739e-05                          0.007341
# 51               5.896335e-05                          0.007885
# 52               2.928970e-05                          0.007452
# 53               3.653675e-05                          0.009889
#
#     L_sartorius_boundary_iou_3d
# 0                      0.635402
# 1                      0.666312
# 2                      0.611927
# 3                      0.661677
# 4                      0.643029
# 5                      0.671402
# 6                      0.593340
# 7                      0.623708
# 8                      0.628343
# 9                      0.621442
# 10                     0.631162
# 11                     0.611451
# 12                     0.618251
# 13                     0.698645
# 14                     0.651774
# 15                     0.678195
# 16                     0.642877
# 17                     0.686200
# 18                     0.671362
# 19                     0.657261
# 20                     0.644664
# 21                     0.621587
# 22                     0.630833
# 23                     0.692412
# 24                     0.570709
# 25                     0.566312
# 26                     0.671322
# 27                     0.666533
# 28                     0.556775
# 29                     0.644036
# 30                     0.592348
# 31                     0.651304
# 32                     0.589338
# 33                     0.656828
# 34                     0.430491
# 35                     0.298557
# 36                     0.437241
# 37                     0.364416
# 38                     0.397926
# 39                     0.420328
# 40                     0.418744
# 41                     0.303411
# 42                     0.440081
# 43                     0.556291
# 44                     0.500661
# 45                     0.556414
# 46                     0.487816
# 47                     0.322374
# 48                     0.585461
# 49                     0.493795
# 50                     0.545111
# 51                     0.583226
# 52                     0.581754
# 53                     0.359888
